# %%
# rainfall_models_adilabad.py
# Three pipelines (CNN-LSTM, Transformer, TabNet+Sequence) sharing the same preprocessing.
# Author: (adapted for your request)
# in this, i have added more lag features (lag14, lag30) - helps in focusing on large monthly seasonal cycle

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, roc_auc_score, roc_curve, auc
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# -----------------------------
# Config (change as needed)
# -----------------------------
DATA_FILES = {
    2019: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\hyderabad_2019.csv",
    2020: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\hyderabad_2020.csv",
    2021: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\hyderabad_2021.csv",
    2022: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\hyderabad_2022.csv",
    2023: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\hyderabad_2023.csv",
    2024: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\hyderabad_2024.csv",
}
TRAIN_YEARS = [2019, 2020, 2021,2022,2023]  #, 2022, 2023
TEST_YEAR = 2024
SEQ_LENGTH = 30       # sliding window length (you can increase to 30/60 to see effects)
BATCH_SIZE = 32
EPOCHS = 100
RANDOM_STATE = 42

# -----------------------------
# Utility: load + prepare dataset
# -----------------------------
def load_and_prepare_data(file_map=DATA_FILES):
    # load all csvs listed in file_map (keys = year)
    dfs = []
    for year in sorted(file_map.keys()):
        path = file_map[year]
        df = pd.read_csv(path).assign(YEAR=year)
        dfs.append(df)
    full_df = pd.concat(dfs, ignore_index=True)

    # required columns check (match your earlier code)
    required_cols = ['YEAR', 'MO', 'DY', 'PRECTOTCORR']
    missing = [c for c in required_cols if c not in full_df.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    # ensure numeric
    for c in required_cols:
        full_df[c] = pd.to_numeric(full_df[c], errors='coerce')
    full_df.dropna(subset=required_cols, inplace=True)

    # datetime and cyclic DOY features
    full_df['datetime'] = pd.to_datetime(dict(year=full_df['YEAR'], month=full_df['MO'], day=full_df['DY']))
    full_df['DOY'] = full_df['datetime'].dt.dayofyear
    full_df['sin_DOY'] = np.sin(2*np.pi*full_df['DOY']/365.25)
    full_df['cos_DOY'] = np.cos(2*np.pi*full_df['DOY']/365.25)

    # lags
    for lag in [1, 3, 7, 14, 30]:
        full_df[f'PRECTOTCORR_lag{lag}'] = full_df['PRECTOTCORR'].shift(lag)

    # sea level temp: hyderabad elev = 536m (your formula)
    full_df['SLT'] = full_df['TS'] + (0.0065 * 536)

    # drop any remaining NaNs
    full_df.dropna(inplace=True)

    # features and target (binary)
    features = ['SLT', 'SLP', 'T2M', 'TS', 'T2M_MAX', 'T2M_MIN',
            'RH2M', 'WS10M_MAX', 'WS10M_MIN',
            'sin_DOY', 'cos_DOY',
            'PRECTOTCORR_lag1', 'PRECTOTCORR_lag3', 'PRECTOTCORR_lag7',
            'PRECTOTCORR_lag14', 'PRECTOTCORR_lag30']

    full_df['Rain'] = (full_df['PRECTOTCORR'] > 0).astype(int)

    train_df = full_df[full_df['YEAR'].isin(TRAIN_YEARS)].copy()
    test_df = full_df[full_df['YEAR'] == TEST_YEAR].copy()

    # temporal leakage check
    if len(train_df) == 0 or len(test_df) == 0:
        raise ValueError("Train or test data empty. Check years and files.")
    if test_df['datetime'].min() <= train_df['datetime'].max():
        # Typically okay as long as test is separate year; still keep check
        pass

    print("TRAIN SIZE:", len(train_df), "TEST SIZE:", len(test_df))
    print("Train class distribution:\n", train_df['Rain'].value_counts(normalize=True))
    return train_df, test_df, features, 'Rain'

# -----------------------------
# Preprocess: scaling + SMOTE + sequences
# -----------------------------
def preprocess_and_balance(train_df, test_df, features, target):
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(train_df[features])
    X_test_scaled = scaler.transform(test_df[features])

    # SMOTE on training data (tabular)
    sm = SMOTE(random_state=RANDOM_STATE)
    X_res, y_res = sm.fit_resample(X_train_scaled, train_df[target].values)

    # create balanced train DataFrame (ordered by resample index -> shuffled)
    train_balanced = pd.DataFrame(X_res, columns=features)
    train_balanced[target] = y_res

    test_processed = pd.DataFrame(X_test_scaled, columns=features, index=test_df.index)
    test_processed[target] = test_df[target].values
    test_processed['DOY'] = test_df['DOY']

    print("After SMOTE balancing:", train_balanced[target].value_counts())
    return train_balanced, test_processed, scaler

def create_sequences(data_df, features, target, seq_length):
    X, y = [], []
    for i in range(len(data_df) - seq_length):
        X.append(data_df[features].iloc[i:i+seq_length].values)
        y.append(data_df[target].iloc[i+seq_length])
    X = np.array(X)
    y = np.array(y)
    return X, y

# -----------------------------
# Model A: CNN-LSTM
# -----------------------------
def build_cnn_lstm(seq_len, n_features):
    inp = Input(shape=(seq_len, n_features))
    x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(inp)
    x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = LSTM(64)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.3)(x)
    out = Dense(1, activation='sigmoid')(x)
    model = Model(inp, out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    model.summary()
    return model

# -----------------------------
# Model B: Transformer (simple encoder)
# -----------------------------
def build_transformer_binary(seq_len, n_features, d_model=128, heads=4, ff_dim=256):
    inp = Input(shape=(seq_len, n_features))
    # linear projection to d_model
    x = Dense(d_model)(inp)
    # learnable positional embedding
    pos_emb = tf.Variable(tf.random.normal([1, seq_len, d_model]), trainable=True)
    x = x + pos_emb

    for _ in range(2):  # two encoder blocks
        attn = MultiHeadAttention(num_heads=heads, key_dim=d_model//heads)(x, x)
        attn = Dropout(0.2)(attn)
        x = LayerNormalization()(x + attn)

        ffn = Dense(ff_dim, activation='relu')(x)
        ffn = Dense(d_model)(ffn)
        ffn = Dropout(0.2)(ffn)
        x = LayerNormalization()(x + ffn)

    x = GlobalAveragePooling1D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    out = Dense(1, activation='sigmoid')(x)
    model = Model(inp, out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    model.summary()
    return model

# -----------------------------
# Model C: TabNet + Sequence hybrid (custom sparsemax implemented)
# -----------------------------
def sparsemax(logits, axis=-1):
    logits = tf.cast(logits, tf.float32)
    z = tf.sort(logits, direction='DESCENDING', axis=axis)
    z_cumsum = tf.cumsum(z, axis=axis)
    k = tf.range(1, tf.shape(z)[-1] + 1, dtype=tf.float32)
    k_shape = [1] * (len(logits.shape) - 1) + [-1]
    k = tf.reshape(k, k_shape)
    support = tf.cast(1 + k * z > z_cumsum, tf.float32)
    k_z = tf.reduce_sum(support, axis=axis, keepdims=True)
    tau = (tf.reduce_sum(z * support, axis=axis, keepdims=True) - 1.0) / k_z
    return tf.maximum(0.0, logits - tau)

def tabnet_block(inputs, input_dim, feature_dim=64, output_dim=32, steps=4, gamma=1.5):

    # Prior initialized as ones but using a Lambda layer
    prior = Lambda(lambda x: tf.ones_like(x))(inputs)

    outputs = []

    for i in range(steps):

        # Step 1: Attentive transformer (Mask)
        mask_logits = Dense(input_dim)(prior)
        
        # sparsemax using Lambda so Keras accepts it
        mask = Lambda(lambda x: sparsemax(x))(mask_logits)

        # masked inputs
        masked_data = Multiply()([inputs, mask])

        # Step 2: Feature transformer
        feat = Dense(feature_dim, activation="relu")(masked_data)
        feat = Dense(output_dim, activation="relu")(feat)

        outputs.append(feat)

        # Update prior = prior * (gamma - mask)
        prior = Multiply()([prior, Lambda(lambda x: gamma - x)(mask)])

    # Combine outputs
    out = Add()(outputs)  
    return out


def sequence_branch(seq_inp, hidden=64):
    # small CNN+GRU branch
    x = Conv1D(32, 3, padding='same', activation='relu')(seq_inp)
    x = MaxPooling1D(2)(x)
    x = GRU(hidden, return_sequences=False)(x)
    x = Dense(64, activation='relu')(x)
    return x

def build_tabnet_hybrid(seq_len, n_features, tab_feature_dim=64, tab_output_dim=32, seq_hidden=64):
    seq_inp = Input(shape=(seq_len, n_features))
    tab_inp = Input(shape=(n_features,))

    seq_out = sequence_branch(seq_inp, hidden=seq_hidden)
    tab_out = tabnet_block(tab_inp, input_dim=n_features, feature_dim=tab_feature_dim, output_dim=tab_output_dim, steps=4)

    merged = Concatenate()([seq_out, tab_out])
    x = Dense(64, activation='relu')(merged)
    x = Dropout(0.3)(x)
    out = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=[seq_inp, tab_inp], outputs=out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    model.summary()
    return model

# -----------------------------
# Training + evaluation helpers
# -----------------------------
def plot_history(history, title="Training"):
    plt.figure(figsize=(10,4))
    plt.plot(history.history['loss'], label='train loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='val loss')
    plt.title(title)
    plt.legend()
    plt.show()

def evaluate_and_print(y_true, y_prob):
    y_pred = (y_prob > 0.5).astype(int).ravel()
    print("Accuracy:", accuracy_score(y_true, y_pred))
    print("Precision:", precision_score(y_true, y_pred))
    print("Recall:", recall_score(y_true, y_pred))
    print("F1:", f1_score(y_true, y_pred))
    print("ROC-AUC:", roc_auc_score(y_true, y_prob))
    print("Confusion matrix:\n", confusion_matrix(y_true, y_pred))
    print(classification_report(y_true, y_pred, digits=4))

# -----------------------------
# End-to-end train functions
# -----------------------------
def train_cnn_lstm_pipeline(seq_len=SEQ_LENGTH):
    train_df, test_df, features, target = load_and_prepare_data()
    train_balanced, test_processed, scaler = preprocess_and_balance(train_df, test_df, features, target)

    X_train, y_train = create_sequences(train_balanced, features, target, seq_len)
    X_test, y_test = create_sequences(test_processed, features, target, seq_len)

    print("Shapes:", X_train.shape, y_train.shape, X_test.shape, y_test.shape)
    model = build_cnn_lstm(seq_len, len(features))
    cbs = [EarlyStopping(patience=12, restore_best_weights=True), ReduceLROnPlateau(patience=5, factor=0.5)]
    history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=cbs, verbose=1)
    plot_history(history, "CNN-LSTM Loss")
    y_prob = model.predict(X_test).ravel()
    evaluate_and_print(y_test, y_prob)
    return model, scaler, test_processed, features

def train_transformer_pipeline(seq_len=SEQ_LENGTH):
    train_df, test_df, features, target = load_and_prepare_data()
    train_balanced, test_processed, scaler = preprocess_and_balance(train_df, test_df, features, target)

    X_train, y_train = create_sequences(train_balanced, features, target, seq_len)
    X_test, y_test = create_sequences(test_processed, features, target, seq_len)

    model = build_transformer_binary(seq_len, len(features))
    cbs = [EarlyStopping(patience=12, restore_best_weights=True), ReduceLROnPlateau(patience=5, factor=0.5)]
    history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=cbs, verbose=1)
    plot_history(history, "Transformer Loss")
    y_prob = model.predict(X_test).ravel()
    evaluate_and_print(y_test, y_prob)
    return model, scaler, test_processed, features

def train_tabnet_hybrid_pipeline(seq_len=SEQ_LENGTH):
    train_df, test_df, features, target = load_and_prepare_data()
    train_balanced, test_processed, scaler = preprocess_and_balance(train_df, test_df, features, target)

    X_train_seq, y_train = create_sequences(train_balanced, features, target, seq_len)
    X_test_seq, y_test = create_sequences(test_processed, features, target, seq_len)

    # For tabular branch we use the last day's features as tabular input
    X_train_tab = X_train_seq[:, -1, :]
    X_test_tab = X_test_seq[:, -1, :]

    model = build_tabnet_hybrid(seq_len, len(features))
    # compute class weights from original train (before SMOTE)
    orig_train_df = pd.concat([train_df for train_df in [train_df]], ignore_index=False)  # placeholder to keep same var name
    # compute class weights from y_train (balanced training after SMOTE not appropriate for weighting)
    cw_vals = compute_class_weight("balanced", classes=np.array([0,1]), y=y_train)
    class_weights = {0: cw_vals[0], 1: cw_vals[1]}

    cbs = [EarlyStopping(patience=12, restore_best_weights=True), ReduceLROnPlateau(patience=5, factor=0.5)]
    history = model.fit([X_train_seq, X_train_tab], y_train, epochs=EPOCHS, batch_size=BATCH_SIZE,
                        validation_split=0.2, callbacks=cbs, class_weight=class_weights, verbose=1)
    plot_history(history, "TabNet+Seq Loss")
    y_prob = model.predict([X_test_seq, X_test_tab]).ravel()
    evaluate_and_print(y_test, y_prob)
    return model, scaler, test_processed, features

# -----------------------------
# Main: choose which pipelines to run
# -----------------------------
if __name__ == "__main__":
    # Pick the model(s) you want to run. Running all three will take longer.

    print("Running CNN-LSTM pipeline...")
    model_cnn, scaler, test_processed, features = train_cnn_lstm_pipeline(seq_len=SEQ_LENGTH)
    X_test, y_test = create_sequences(test_processed, features, "Rain", SEQ_LENGTH)
    y_prob_cnn = model_cnn.predict(X_test).ravel()
    y_pred_cnn = (y_prob_cnn > 0.5).astype(int)

    print("\nRunning Transformer pipeline...")
    model_tr, scaler, test_processed, features = train_transformer_pipeline(seq_len=SEQ_LENGTH)
    X_test, y_test = create_sequences(test_processed, features, "Rain", SEQ_LENGTH)
    y_prob_tr = model_tr.predict(X_test).ravel()
    y_pred_tr = (y_prob_tr > 0.5).astype(int)

    print("\nRunning TabNet+Sequence pipeline...")
    model_tab, scaler, test_processed, features = train_tabnet_hybrid_pipeline(seq_len=SEQ_LENGTH)
    X_test, y_test = create_sequences(test_processed, features, "Rain", SEQ_LENGTH)
    y_prob_tab = model_tab.predict([X_test, X_test[:, -1, :]]).ravel()
    y_pred_tab = (y_prob_tab > 0.5).astype(int)
# Out:
# Running CNN-LSTM pipeline...
# TRAIN SIZE: 1796 TEST SIZE: 366
# Train class distribution:
#  Rain
# 1    0.568486
# 0    0.431514
# Name: proportion, dtype: float64
# After SMOTE balancing: Rain
# 0    1021
# 1    1021
# Name: count, dtype: int64
# Shapes: (2012, 30, 16) (2012,) (336, 30, 16) (336,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 30, 64)         │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 30, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 15, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,737 (206.00 KB)
#  Trainable params: 52,737 (206.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.6140 - auc: 0.6566 - loss: 0.6670 - precision: 0.6066 - recall: 0.9518 - val_accuracy: 0.2804 - val_auc: 0.7937 - val_loss: 0.7085 - val_precision: 0.2161 - val_recall: 0.9176 - learning_rate: 1.0000e-04
# Epoch 2/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7688 - auc: 0.8355 - loss: 0.5596 - precision: 0.7489 - recall: 0.9046 - val_accuracy: 0.8834 - val_auc: 0.8767 - val_loss: 0.5220 - val_precision: 0.7021 - val_recall: 0.7765 - learning_rate: 1.0000e-04
# Epoch 3/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8067 - auc: 0.8677 - loss: 0.4551 - precision: 0.8380 - recall: 0.8264 - val_accuracy: 0.8908 - val_auc: 0.9269 - val_loss: 0.4053 - val_precision: 0.7204 - val_recall: 0.7882 - learning_rate: 1.0000e-04
# Epoch 4/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8111 - auc: 0.8715 - loss: 0.4425 - precision: 0.8400 - recall: 0.8328 - val_accuracy: 0.8933 - val_auc: 0.9161 - val_loss: 0.3682 - val_precision: 0.7333 - val_recall: 0.7765 - learning_rate: 1.0000e-04
# Epoch 5/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8048 - auc: 0.8795 - loss: 0.4332 - precision: 0.8360 - recall: 0.8253 - val_accuracy: 0.8883 - val_auc: 0.9192 - val_loss: 0.3812 - val_precision: 0.7174 - val_recall: 0.7765 - learning_rate: 1.0000e-04
# Epoch 6/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8073 - auc: 0.8822 - loss: 0.4274 - precision: 0.8339 - recall: 0.8339 - val_accuracy: 0.8883 - val_auc: 0.9222 - val_loss: 0.4054 - val_precision: 0.7128 - val_recall: 0.7882 - learning_rate: 1.0000e-04
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8111 - auc: 0.8784 - loss: 0.4312 - precision: 0.8371 - recall: 0.8371 - val_accuracy: 0.8859 - val_auc: 0.9070 - val_loss: 0.4314 - val_precision: 0.7053 - val_recall: 0.7882 - learning_rate: 1.0000e-04
# Epoch 8/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8104 - auc: 0.8785 - loss: 0.4305 - precision: 0.8340 - recall: 0.8403 - val_accuracy: 0.8933 - val_auc: 0.9215 - val_loss: 0.3524 - val_precision: 0.7333 - val_recall: 0.7765 - learning_rate: 1.0000e-04
# Epoch 9/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8148 - auc: 0.8851 - loss: 0.4214 - precision: 0.8447 - recall: 0.8339 - val_accuracy: 0.8859 - val_auc: 0.9166 - val_loss: 0.4228 - val_precision: 0.7053 - val_recall: 0.7882 - learning_rate: 1.0000e-04
# Epoch 10/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8111 - auc: 0.8843 - loss: 0.4207 - precision: 0.8371 - recall: 0.8371 - val_accuracy: 0.8859 - val_auc: 0.9207 - val_loss: 0.4280 - val_precision: 0.7053 - val_recall: 0.7882 - learning_rate: 1.0000e-04
# Epoch 11/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8142 - auc: 0.8853 - loss: 0.4196 - precision: 0.8380 - recall: 0.8424 - val_accuracy: 0.8834 - val_auc: 0.9139 - val_loss: 0.4365 - val_precision: 0.6979 - val_recall: 0.7882 - learning_rate: 1.0000e-04
# Epoch 12/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8173 - auc: 0.8848 - loss: 0.4186 - precision: 0.8367 - recall: 0.8510 - val_accuracy: 0.8883 - val_auc: 0.9237 - val_loss: 0.3614 - val_precision: 0.7174 - val_recall: 0.7765 - learning_rate: 1.0000e-04
# Epoch 13/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8148 - auc: 0.8847 - loss: 0.4207 - precision: 0.8455 - recall: 0.8328 - val_accuracy: 0.8859 - val_auc: 0.9164 - val_loss: 0.4249 - val_precision: 0.7053 - val_recall: 0.7882 - learning_rate: 1.0000e-04
# Epoch 14/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8148 - auc: 0.8870 - loss: 0.4150 - precision: 0.8346 - recall: 0.8489 - val_accuracy: 0.8883 - val_auc: 0.9260 - val_loss: 0.4052 - val_precision: 0.7128 - val_recall: 0.7882 - learning_rate: 5.0000e-05
# Epoch 15/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8104 - auc: 0.8824 - loss: 0.4228 - precision: 0.8340 - recall: 0.8403 - val_accuracy: 0.8859 - val_auc: 0.9176 - val_loss: 0.4156 - val_precision: 0.7053 - val_recall: 0.7882 - learning_rate: 5.0000e-05
# Epoch 16/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8154 - auc: 0.8888 - loss: 0.4133 - precision: 0.8362 - recall: 0.8478 - val_accuracy: 0.8834 - val_auc: 0.9136 - val_loss: 0.4392 - val_precision: 0.6979 - val_recall: 0.7882 - learning_rate: 5.0000e-05
# Epoch 17/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8129 - auc: 0.8857 - loss: 0.4179 - precision: 0.8383 - recall: 0.8392 - val_accuracy: 0.8859 - val_auc: 0.9188 - val_loss: 0.4092 - val_precision: 0.7053 - val_recall: 0.7882 - learning_rate: 5.0000e-05
# Epoch 18/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8135 - auc: 0.8877 - loss: 0.4148 - precision: 0.8392 - recall: 0.8392 - val_accuracy: 0.8883 - val_auc: 0.9204 - val_loss: 0.4013 - val_precision: 0.7128 - val_recall: 0.7882 - learning_rate: 5.0000e-05
# Epoch 19/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8154 - auc: 0.8897 - loss: 0.4124 - precision: 0.8347 - recall: 0.8499 - val_accuracy: 0.8834 - val_auc: 0.9208 - val_loss: 0.4178 - val_precision: 0.6979 - val_recall: 0.7882 - learning_rate: 2.5000e-05
# Epoch 20/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8104 - auc: 0.8893 - loss: 0.4122 - precision: 0.8326 - recall: 0.8424 - val_accuracy: 0.8834 - val_auc: 0.9185 - val_loss: 0.4361 - val_precision: 0.6979 - val_recall: 0.7882 - learning_rate: 2.5000e-05
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Accuracy: 0.8244047619047619
# Precision: 0.8578431372549019
# Recall: 0.8536585365853658
# F1: 0.8557457212713936
# ROC-AUC: 0.8869484267361757
# Confusion matrix:
#  [[102  29]
#  [ 30 175]]
#               precision    recall  f1-score   support
#
#            0     0.7727    0.7786    0.7757       131
#            1     0.8578    0.8537    0.8557       205
#
#     accuracy                         0.8244       336
#    macro avg     0.8153    0.8161    0.8157       336
# weighted avg     0.8247    0.8244    0.8245       336
#
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Running Transformer pipeline...
# TRAIN SIZE: 1796 TEST SIZE: 366
# Train class distribution:
#  Rain
# 1    0.568486
# 0    0.431514
# Name: proportion, dtype: float64
# After SMOTE balancing: Rain
# 0    1021
# 1    1021
# Name: count, dtype: int64
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 30, 16)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 30, 128)   │      2,176 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 30, 128)   │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 128)   │     66,048 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 30, 128)   │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 30, 128)   │          0 │ add[0][0],        │
# │                     │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 30, 128)   │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 30, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 30, 128)   │     32,896 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 30, 128)   │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 30, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 128)   │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 30, 128)   │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 30, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 30, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 30, 128)   │     32,896 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 30, 128)   │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 30, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │     16,512 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1)         │        129 │ dropout_7[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 283,777 (1.08 MB)
#  Trainable params: 283,777 (1.08 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.6756 - auc_1: 0.7342 - loss: 0.6102 - precision_1: 0.6725 - recall_1: 0.8585 - val_accuracy: 0.8784 - val_auc_1: 0.8765 - val_loss: 0.5538 - val_precision_1: 0.6837 - val_recall_1: 0.7882 - learning_rate: 1.0000e-04
# Epoch 2/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8092 - auc_1: 0.8654 - loss: 0.4579 - precision_1: 0.8247 - recall_1: 0.8521 - val_accuracy: 0.8883 - val_auc_1: 0.8931 - val_loss: 0.3774 - val_precision_1: 0.7128 - val_recall_1: 0.7882 - learning_rate: 1.0000e-04
# Epoch 3/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8123 - auc_1: 0.8731 - loss: 0.4391 - precision_1: 0.8418 - recall_1: 0.8328 - val_accuracy: 0.9057 - val_auc_1: 0.8894 - val_loss: 0.3119 - val_precision_1: 0.7765 - val_recall_1: 0.7765 - learning_rate: 1.0000e-04
# Epoch 4/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8017 - auc_1: 0.8651 - loss: 0.4525 - precision_1: 0.8381 - recall_1: 0.8156 - val_accuracy: 0.8908 - val_auc_1: 0.8908 - val_loss: 0.3799 - val_precision_1: 0.7204 - val_recall_1: 0.7882 - learning_rate: 1.0000e-04
# Epoch 5/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8086 - auc_1: 0.8760 - loss: 0.4346 - precision_1: 0.8423 - recall_1: 0.8242 - val_accuracy: 0.8784 - val_auc_1: 0.8820 - val_loss: 0.4764 - val_precision_1: 0.6800 - val_recall_1: 0.8000 - learning_rate: 1.0000e-04
# Epoch 6/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8005 - auc_1: 0.8722 - loss: 0.4413 - precision_1: 0.8242 - recall_1: 0.8339 - val_accuracy: 0.8834 - val_auc_1: 0.8775 - val_loss: 0.4359 - val_precision_1: 0.6979 - val_recall_1: 0.7882 - learning_rate: 1.0000e-04
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8086 - auc_1: 0.8701 - loss: 0.4440 - precision_1: 0.8321 - recall_1: 0.8392 - val_accuracy: 0.8908 - val_auc_1: 0.8755 - val_loss: 0.4022 - val_precision_1: 0.7204 - val_recall_1: 0.7882 - learning_rate: 1.0000e-04
# Epoch 8/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8092 - auc_1: 0.8781 - loss: 0.4335 - precision_1: 0.8302 - recall_1: 0.8435 - val_accuracy: 0.8883 - val_auc_1: 0.8756 - val_loss: 0.3686 - val_precision_1: 0.7174 - val_recall_1: 0.7765 - learning_rate: 1.0000e-04
# Epoch 9/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8098 - auc_1: 0.8798 - loss: 0.4300 - precision_1: 0.8324 - recall_1: 0.8414 - val_accuracy: 0.8908 - val_auc_1: 0.8766 - val_loss: 0.3574 - val_precision_1: 0.7253 - val_recall_1: 0.7765 - learning_rate: 5.0000e-05
# Epoch 10/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8042 - auc_1: 0.8783 - loss: 0.4314 - precision_1: 0.8337 - recall_1: 0.8274 - val_accuracy: 0.8908 - val_auc_1: 0.8748 - val_loss: 0.3854 - val_precision_1: 0.7204 - val_recall_1: 0.7882 - learning_rate: 5.0000e-05
# Epoch 11/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8135 - auc_1: 0.8774 - loss: 0.4321 - precision_1: 0.8400 - recall_1: 0.8382 - val_accuracy: 0.8908 - val_auc_1: 0.8736 - val_loss: 0.3649 - val_precision_1: 0.7253 - val_recall_1: 0.7765 - learning_rate: 5.0000e-05
# Epoch 12/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8104 - auc_1: 0.8778 - loss: 0.4310 - precision_1: 0.8333 - recall_1: 0.8414 - val_accuracy: 0.8784 - val_auc_1: 0.8734 - val_loss: 0.4562 - val_precision_1: 0.6837 - val_recall_1: 0.7882 - learning_rate: 5.0000e-05
# Epoch 13/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8173 - auc_1: 0.8827 - loss: 0.4240 - precision_1: 0.8360 - recall_1: 0.8521 - val_accuracy: 0.8883 - val_auc_1: 0.8740 - val_loss: 0.3651 - val_precision_1: 0.7174 - val_recall_1: 0.7765 - learning_rate: 5.0000e-05
# Epoch 14/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8080 - auc_1: 0.8819 - loss: 0.4261 - precision_1: 0.8348 - recall_1: 0.8339 - val_accuracy: 0.8883 - val_auc_1: 0.8739 - val_loss: 0.4038 - val_precision_1: 0.7128 - val_recall_1: 0.7882 - learning_rate: 2.5000e-05
# Epoch 15/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8154 - auc_1: 0.8833 - loss: 0.4231 - precision_1: 0.8362 - recall_1: 0.8478 - val_accuracy: 0.8883 - val_auc_1: 0.8739 - val_loss: 0.3989 - val_precision_1: 0.7128 - val_recall_1: 0.7882 - learning_rate: 2.5000e-05
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Accuracy: 0.8184523809523809
# Precision: 0.8913043478260869
# Recall: 0.8
# F1: 0.8431876606683805
# ROC-AUC: 0.8910072612176504
# Confusion matrix:
#  [[111  20]
#  [ 41 164]]
#               precision    recall  f1-score   support
#
#            0     0.7303    0.8473    0.7845       131
#            1     0.8913    0.8000    0.8432       205
#
#     accuracy                         0.8185       336
#    macro avg     0.8108    0.8237    0.8138       336
# weighted avg     0.8285    0.8185    0.8203       336
#
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# Running TabNet+Sequence pipeline...
# TRAIN SIZE: 1796 TEST SIZE: 366
# Train class distribution:
#  Rain
# 1    0.568486
# 0    0.431514
# Name: proportion, dtype: float64
# After SMOTE balancing: Rain
# 0    1021
# 1    1021
# Name: count, dtype: int64
# WARNING:tensorflow:From c:\Users\priya\miniconda3\envs\rainfall\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 16)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 16)        │          0 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 16)        │        272 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 16)        │          0 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 16)        │          0 │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 16)        │          0 │ lambda[0][0],     │
# │ (Multiply)          │                   │            │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 16)        │        272 │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 16)        │          0 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 16)        │          0 │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 16)        │          0 │ multiply_1[0][0], │
# │ (Multiply)          │                   │            │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 16)        │        272 │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 16)        │          0 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 16)        │          0 │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 16)        │          0 │ multiply_3[0][0], │
# │ (Multiply)          │                   │            │ lambda_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 16)        │        272 │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 30, 16)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 16)        │          0 │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 30, 32)    │      1,568 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 16)        │          0 │ input_layer_3[0]… │
# │                     │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 16)        │          0 │ input_layer_3[0]… │
# │ (Multiply)          │                   │            │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 16)        │          0 │ input_layer_3[0]… │
# │ (Multiply)          │                   │            │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 16)        │          0 │ input_layer_3[0]… │
# │ (Multiply)          │                   │            │ lambda_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 15, 32)    │          0 │ conv1d_2[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 64)        │      1,088 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 64)        │      1,088 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 64)        │      1,088 │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 64)        │      1,088 │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 64)        │     18,816 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 32)        │      2,080 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 32)        │      2,080 │ dense_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 32)        │      2,080 │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 32)        │      2,080 │ dense_20[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │      4,160 │ gru[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 32)        │          0 │ dense_12[0][0],   │
# │                     │                   │            │ dense_15[0][0],   │
# │                     │                   │            │ dense_18[0][0],   │
# │                     │                   │            │ dense_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 96)        │          0 │ dense_9[0][0],    │
# │ (Concatenate)       │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 64)        │      6,208 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64)        │          0 │ dense_22[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 1)         │         65 │ dropout_8[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 44,577 (174.13 KB)
#  Trainable params: 44,577 (174.13 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7676 - auc_2: 0.8168 - loss: 0.5530 - precision_2: 0.7615 - recall_2: 0.8725 - val_accuracy: 0.8834 - val_auc_2: 0.9045 - val_loss: 0.4051 - val_precision_2: 0.6979 - val_recall_2: 0.7882 - learning_rate: 0.0010
# Epoch 2/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8067 - auc_2: 0.8705 - loss: 0.4449 - precision_2: 0.8193 - recall_2: 0.8553 - val_accuracy: 0.9082 - val_auc_2: 0.9000 - val_loss: 0.3344 - val_precision_2: 0.7857 - val_recall_2: 0.7765 - learning_rate: 0.0010
# Epoch 3/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8173 - auc_2: 0.8844 - loss: 0.4211 - precision_2: 0.8395 - recall_2: 0.8467 - val_accuracy: 0.8586 - val_auc_2: 0.9094 - val_loss: 0.4424 - val_precision_2: 0.6321 - val_recall_2: 0.7882 - learning_rate: 0.0010
# Epoch 4/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8129 - auc_2: 0.8869 - loss: 0.4172 - precision_2: 0.8305 - recall_2: 0.8510 - val_accuracy: 0.8834 - val_auc_2: 0.9138 - val_loss: 0.3722 - val_precision_2: 0.7021 - val_recall_2: 0.7765 - learning_rate: 0.0010
# Epoch 5/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8142 - auc_2: 0.8925 - loss: 0.4091 - precision_2: 0.8416 - recall_2: 0.8371 - val_accuracy: 0.7370 - val_auc_2: 0.9094 - val_loss: 0.5605 - val_precision_2: 0.4379 - val_recall_2: 0.8706 - learning_rate: 0.0010
# Epoch 6/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8241 - auc_2: 0.8977 - loss: 0.4006 - precision_2: 0.8421 - recall_2: 0.8574 - val_accuracy: 0.8759 - val_auc_2: 0.9095 - val_loss: 0.3728 - val_precision_2: 0.6768 - val_recall_2: 0.7882 - learning_rate: 0.0010
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8191 - auc_2: 0.8966 - loss: 0.4019 - precision_2: 0.8323 - recall_2: 0.8617 - val_accuracy: 0.8065 - val_auc_2: 0.9232 - val_loss: 0.4554 - val_precision_2: 0.5259 - val_recall_2: 0.8353 - learning_rate: 0.0010
# Epoch 8/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8310 - auc_2: 0.9072 - loss: 0.3804 - precision_2: 0.8512 - recall_2: 0.8585 - val_accuracy: 0.8313 - val_auc_2: 0.9159 - val_loss: 0.4062 - val_precision_2: 0.5726 - val_recall_2: 0.7882 - learning_rate: 5.0000e-04
# Epoch 9/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8359 - auc_2: 0.9096 - loss: 0.3767 - precision_2: 0.8532 - recall_2: 0.8660 - val_accuracy: 0.8189 - val_auc_2: 0.9218 - val_loss: 0.4057 - val_precision_2: 0.5476 - val_recall_2: 0.8118 - learning_rate: 5.0000e-04
# Epoch 10/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8415 - auc_2: 0.9125 - loss: 0.3707 - precision_2: 0.8509 - recall_2: 0.8810 - val_accuracy: 0.7891 - val_auc_2: 0.9259 - val_loss: 0.4433 - val_precision_2: 0.5000 - val_recall_2: 0.8588 - learning_rate: 5.0000e-04
# Epoch 11/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8428 - auc_2: 0.9127 - loss: 0.3706 - precision_2: 0.8664 - recall_2: 0.8617 - val_accuracy: 0.7990 - val_auc_2: 0.9139 - val_loss: 0.4190 - val_precision_2: 0.5145 - val_recall_2: 0.8353 - learning_rate: 5.0000e-04
# Epoch 12/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8415 - auc_2: 0.9171 - loss: 0.3612 - precision_2: 0.8509 - recall_2: 0.8810 - val_accuracy: 0.8362 - val_auc_2: 0.9270 - val_loss: 0.3668 - val_precision_2: 0.5785 - val_recall_2: 0.8235 - learning_rate: 5.0000e-04
# Epoch 13/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8465 - auc_2: 0.9208 - loss: 0.3525 - precision_2: 0.8633 - recall_2: 0.8735 - val_accuracy: 0.7792 - val_auc_2: 0.9200 - val_loss: 0.4413 - val_precision_2: 0.4867 - val_recall_2: 0.8588 - learning_rate: 2.5000e-04
# Epoch 14/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8490 - auc_2: 0.9201 - loss: 0.3537 - precision_2: 0.8594 - recall_2: 0.8842 - val_accuracy: 0.7667 - val_auc_2: 0.9233 - val_loss: 0.4614 - val_precision_2: 0.4710 - val_recall_2: 0.8588 - learning_rate: 2.5000e-04
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Accuracy: 0.8273809523809523
# Precision: 0.8730964467005076
# Recall: 0.8390243902439024
# F1: 0.8557213930348259
# ROC-AUC: 0.8878793520759636
# Confusion matrix:
#  [[106  25]
#  [ 33 172]]
#               precision    recall  f1-score   support
#
#            0     0.7626    0.8092    0.7852       131
#            1     0.8731    0.8390    0.8557       205
#
#     accuracy                         0.8274       336
#    macro avg     0.8178    0.8241    0.8205       336
# weighted avg     0.8300    0.8274    0.8282       336
#
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Number of points to display
N = 150  

plt.figure(figsize=(16, 6))

# Plot Actual
plt.plot(y_test[:N], 'ko-', label="Actual", linewidth=2, markersize=4, alpha=0.9)

# Plot CNN-LSTM Predictions
plt.plot(y_pred_cnn[:N], 'r--', label="CNN-LSTM Prediction", linewidth=1.8, alpha=0.8)

# Plot Transformer Predictions
plt.plot(y_pred_tr[:N], 'b-.', label="Transformer Based Binary Classifier Prediction", linewidth=1.8, alpha=0.8)

# Plot TabNet+Sequence Predictions
plt.plot(y_pred_tab[:N], 'g:', label="TabNet+(GRU-CNN) Sequence Hybrid Prediction", linewidth=2.2, alpha=0.9)

# Graph formatting
plt.title("Hyderabad – Actual vs Predicted Rainfall (All Models)", fontsize=14)
plt.xlabel("Time Steps", fontsize=12)
plt.ylabel("Rain (1) / No Rain (0)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# --------------------------
# COLLECT METRICS FOR MODELS
# --------------------------

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

metrics = {}

def compute_metrics(y_true, y_prob):
    y_pred = (y_prob > 0.5).astype(int)
    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1": f1_score(y_true, y_pred),
        "ROC-AUC": roc_auc_score(y_true, y_prob)
    }

metrics["CNN-LSTM"] = compute_metrics(y_test, y_prob_cnn)
metrics["Transformer"] = compute_metrics(y_test, y_prob_tr)
metrics["TabNet+Seq(GRU+CNN)"] = compute_metrics(y_test, y_prob_tab)

print("\nCollected Metrics:")
metrics
# Out:
# Collected Metrics:
# {'CNN-LSTM': {'Accuracy': 0.8273809523809523,
#   'Precision': 0.855072463768116,
#   'Recall': 0.8634146341463415,
#   'F1': 0.8592233009708737,
#   'ROC-AUC': 0.8910444982312419},
#  'Transformer': {'Accuracy': 0.8303571428571429,
#   'Precision': 0.8894736842105263,
#   'Recall': 0.824390243902439,
#   'F1': 0.8556962025316456,
#   'ROC-AUC': 0.8845280208527277},
#  'TabNet+Seq(GRU+CNN)': {'Accuracy': 0.8482142857142857,
#   'Precision': 0.9277777777777778,
#   'Recall': 0.8146341463414634,
#   'F1': 0.8675324675324675,
#   'ROC-AUC': 0.92355241109663}}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Metrics in order
metric_names = ["Accuracy", "Precision", "Recall", "F1", "ROC-AUC"]

# Model names
model_names = list(metrics.keys())

# Create matrix of metric values
values = np.array([[metrics[m][metric] * 100 for metric in metric_names] for m in model_names])

# Plot
plt.figure(figsize=(16, 8))

x = np.arange(len(metric_names))
width = 0.25  # bar width

# Colors
colors = ["#4C72B0", "#55A868", "#C44E52"]

for i, model in enumerate(model_names):
    plt.bar(x + i * width, values[i], width, label=model, color=colors[i], alpha=0.85)
    # Add value labels above bars
    for j, val in enumerate(values[i]):
        plt.text(x[j] + i * width, val + 0.3, f"{val:.2f}", ha='center', fontsize=10)

plt.xticks(x + width, metric_names, fontsize=12)
plt.ylabel("Percentage (%)", fontsize=14)
plt.title("Hyderabad Model Comparison: CNN-LSTM vs Transformer vs TabNet+Seq(GRU+CNN)", fontsize=16)
plt.legend(fontsize=12,loc='lower left')
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.show()
