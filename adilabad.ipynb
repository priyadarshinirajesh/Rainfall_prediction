# %%
# rainfall_models_adilabad.py
# Three pipelines (CNN-LSTM, Transformer, TabNet+Sequence) sharing the same preprocessing.
# Author: (adapted for your request)
# in this, i have added more lag features (lag14, lag30) - helps in focusing on large monthly seasonal cycle

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, roc_auc_score, roc_curve, auc
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# -----------------------------
# Config (change as needed)
# -----------------------------
DATA_FILES = {
    2019: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2019.csv",
    2020: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2020.csv",
    2021: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2021.csv",
    2022: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2022.csv",
    2023: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2023.csv",
    2024: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2024.csv",
}
TRAIN_YEARS = [2019, 2020, 2021,2022,2023]  #, 2022, 2023
TEST_YEAR = 2024
SEQ_LENGTH = 30       # sliding window length (you can increase to 30/60 to see effects)
BATCH_SIZE = 32
EPOCHS = 100
RANDOM_STATE = 42

# -----------------------------
# Utility: load + prepare dataset
# -----------------------------
def load_and_prepare_data(file_map=DATA_FILES):
    # load all csvs listed in file_map (keys = year)
    dfs = []
    for year in sorted(file_map.keys()):
        path = file_map[year]
        df = pd.read_csv(path).assign(YEAR=year)
        dfs.append(df)
    full_df = pd.concat(dfs, ignore_index=True)

    # required columns check (match your earlier code)
    required_cols = ['YEAR', 'MO', 'DY', 'PRECTOTCORR']
    missing = [c for c in required_cols if c not in full_df.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    # ensure numeric
    for c in required_cols:
        full_df[c] = pd.to_numeric(full_df[c], errors='coerce')
    full_df.dropna(subset=required_cols, inplace=True)

    # datetime and cyclic DOY features
    full_df['datetime'] = pd.to_datetime(dict(year=full_df['YEAR'], month=full_df['MO'], day=full_df['DY']))
    full_df['DOY'] = full_df['datetime'].dt.dayofyear
    full_df['sin_DOY'] = np.sin(2*np.pi*full_df['DOY']/365.25)
    full_df['cos_DOY'] = np.cos(2*np.pi*full_df['DOY']/365.25)

    # lags
    for lag in [1, 3, 7, 14, 30]:
        full_df[f'PRECTOTCORR_lag{lag}'] = full_df['PRECTOTCORR'].shift(lag)

    # sea level temp: adilabad elev = 264m (your formula)
    full_df['SLT'] = full_df['TS'] + (0.0065 * 264)

    # drop any remaining NaNs
    full_df.dropna(inplace=True)

    # features and target (binary)
    features = ['SLT', 'SLP', 'T2M', 'TS', 'T2M_MAX', 'T2M_MIN',
            'RH2M', 'WS10M_MAX', 'WS10M_MIN',
            'sin_DOY', 'cos_DOY',
            'PRECTOTCORR_lag1', 'PRECTOTCORR_lag3', 'PRECTOTCORR_lag7',
            'PRECTOTCORR_lag14', 'PRECTOTCORR_lag30']

    full_df['Rain'] = (full_df['PRECTOTCORR'] > 0).astype(int)

    train_df = full_df[full_df['YEAR'].isin(TRAIN_YEARS)].copy()
    test_df = full_df[full_df['YEAR'] == TEST_YEAR].copy()

    # temporal leakage check
    if len(train_df) == 0 or len(test_df) == 0:
        raise ValueError("Train or test data empty. Check years and files.")
    if test_df['datetime'].min() <= train_df['datetime'].max():
        # Typically okay as long as test is separate year; still keep check
        pass

    print("TRAIN SIZE:", len(train_df), "TEST SIZE:", len(test_df))
    print("Train class distribution:\n", train_df['Rain'].value_counts(normalize=True))
    return train_df, test_df, features, 'Rain'

# -----------------------------
# Preprocess: scaling + SMOTE + sequences
# -----------------------------
def preprocess_and_balance(train_df, test_df, features, target):
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(train_df[features])
    X_test_scaled = scaler.transform(test_df[features])

    # SMOTE on training data (tabular)
    sm = SMOTE(random_state=RANDOM_STATE)
    X_res, y_res = sm.fit_resample(X_train_scaled, train_df[target].values)

    # create balanced train DataFrame (ordered by resample index -> shuffled)
    train_balanced = pd.DataFrame(X_res, columns=features)
    train_balanced[target] = y_res

    test_processed = pd.DataFrame(X_test_scaled, columns=features, index=test_df.index)
    test_processed[target] = test_df[target].values
    test_processed['DOY'] = test_df['DOY']

    print("After SMOTE balancing:", train_balanced[target].value_counts())
    return train_balanced, test_processed, scaler

def create_sequences(data_df, features, target, seq_length):
    X, y = [], []
    for i in range(len(data_df) - seq_length):
        X.append(data_df[features].iloc[i:i+seq_length].values)
        y.append(data_df[target].iloc[i+seq_length])
    X = np.array(X)
    y = np.array(y)
    return X, y

# -----------------------------
# Model A: CNN-LSTM
# -----------------------------
def build_cnn_lstm(seq_len, n_features):
    inp = Input(shape=(seq_len, n_features))
    x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(inp)
    x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = LSTM(64)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.3)(x)
    out = Dense(1, activation='sigmoid')(x)
    model = Model(inp, out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    model.summary()
    return model

# -----------------------------
# Model B: Transformer (simple encoder)
# -----------------------------
def build_transformer_binary(seq_len, n_features, d_model=128, heads=4, ff_dim=256):
    inp = Input(shape=(seq_len, n_features))
    # linear projection to d_model
    x = Dense(d_model)(inp)
    # learnable positional embedding
    pos_emb = tf.Variable(tf.random.normal([1, seq_len, d_model]), trainable=True)
    x = x + pos_emb

    for _ in range(2):  # two encoder blocks
        attn = MultiHeadAttention(num_heads=heads, key_dim=d_model//heads)(x, x)
        attn = Dropout(0.2)(attn)
        x = LayerNormalization()(x + attn)

        ffn = Dense(ff_dim, activation='relu')(x)
        ffn = Dense(d_model)(ffn)
        ffn = Dropout(0.2)(ffn)
        x = LayerNormalization()(x + ffn)

    x = GlobalAveragePooling1D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    out = Dense(1, activation='sigmoid')(x)
    model = Model(inp, out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    model.summary()
    return model

# -----------------------------
# Model C: TabNet + Sequence hybrid (custom sparsemax implemented)
# -----------------------------
def sparsemax(logits, axis=-1):
    logits = tf.cast(logits, tf.float32)
    z = tf.sort(logits, direction='DESCENDING', axis=axis)
    z_cumsum = tf.cumsum(z, axis=axis)
    k = tf.range(1, tf.shape(z)[-1] + 1, dtype=tf.float32)
    k_shape = [1] * (len(logits.shape) - 1) + [-1]
    k = tf.reshape(k, k_shape)
    support = tf.cast(1 + k * z > z_cumsum, tf.float32)
    k_z = tf.reduce_sum(support, axis=axis, keepdims=True)
    tau = (tf.reduce_sum(z * support, axis=axis, keepdims=True) - 1.0) / k_z
    return tf.maximum(0.0, logits - tau)

def tabnet_block(inputs, input_dim, feature_dim=64, output_dim=32, steps=4, gamma=1.5):

    # Prior initialized as ones but using a Lambda layer
    prior = Lambda(lambda x: tf.ones_like(x))(inputs)

    outputs = []

    for i in range(steps):

        # Step 1: Attentive transformer (Mask)
        mask_logits = Dense(input_dim)(prior)
        
        # sparsemax using Lambda so Keras accepts it
        mask = Lambda(lambda x: sparsemax(x))(mask_logits)

        # masked inputs
        masked_data = Multiply()([inputs, mask])

        # Step 2: Feature transformer
        feat = Dense(feature_dim, activation="relu")(masked_data)
        feat = Dense(output_dim, activation="relu")(feat)

        outputs.append(feat)

        # Update prior = prior * (gamma - mask)
        prior = Multiply()([prior, Lambda(lambda x: gamma - x)(mask)])

    # Combine outputs
    out = Add()(outputs)  
    return out


def sequence_branch(seq_inp, hidden=64):
    # small CNN+GRU branch
    x = Conv1D(32, 3, padding='same', activation='relu')(seq_inp)
    x = MaxPooling1D(2)(x)
    x = GRU(hidden, return_sequences=False)(x)
    x = Dense(64, activation='relu')(x)
    return x

def build_tabnet_hybrid(seq_len, n_features, tab_feature_dim=64, tab_output_dim=32, seq_hidden=64):
    seq_inp = Input(shape=(seq_len, n_features))
    tab_inp = Input(shape=(n_features,))

    seq_out = sequence_branch(seq_inp, hidden=seq_hidden)
    tab_out = tabnet_block(tab_inp, input_dim=n_features, feature_dim=tab_feature_dim, output_dim=tab_output_dim, steps=4)

    merged = Concatenate()([seq_out, tab_out])
    x = Dense(64, activation='relu')(merged)
    x = Dropout(0.3)(x)
    out = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=[seq_inp, tab_inp], outputs=out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    model.summary()
    return model

# -----------------------------
# Training + evaluation helpers
# -----------------------------
def plot_history(history, title="Training"):
    plt.figure(figsize=(10,4))
    plt.plot(history.history['loss'], label='train loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='val loss')
    plt.title(title)
    plt.legend()
    plt.show()

def evaluate_and_print(y_true, y_prob):
    y_pred = (y_prob > 0.5).astype(int).ravel()
    print("Accuracy:", accuracy_score(y_true, y_pred))
    print("Precision:", precision_score(y_true, y_pred))
    print("Recall:", recall_score(y_true, y_pred))
    print("F1:", f1_score(y_true, y_pred))
    print("ROC-AUC:", roc_auc_score(y_true, y_prob))
    print("Confusion matrix:\n", confusion_matrix(y_true, y_pred))
    print(classification_report(y_true, y_pred, digits=4))

# -----------------------------
# End-to-end train functions
# -----------------------------
def train_cnn_lstm_pipeline(seq_len=SEQ_LENGTH):
    train_df, test_df, features, target = load_and_prepare_data()
    train_balanced, test_processed, scaler = preprocess_and_balance(train_df, test_df, features, target)

    X_train, y_train = create_sequences(train_balanced, features, target, seq_len)
    X_test, y_test = create_sequences(test_processed, features, target, seq_len)

    print("Shapes:", X_train.shape, y_train.shape, X_test.shape, y_test.shape)
    model = build_cnn_lstm(seq_len, len(features))
    cbs = [EarlyStopping(patience=12, restore_best_weights=True), ReduceLROnPlateau(patience=5, factor=0.5)]
    history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=cbs, verbose=1)
    plot_history(history, "CNN-LSTM Loss")
    y_prob = model.predict(X_test).ravel()
    evaluate_and_print(y_test, y_prob)
    return model, scaler, test_processed, features

def train_transformer_pipeline(seq_len=SEQ_LENGTH):
    train_df, test_df, features, target = load_and_prepare_data()
    train_balanced, test_processed, scaler = preprocess_and_balance(train_df, test_df, features, target)

    X_train, y_train = create_sequences(train_balanced, features, target, seq_len)
    X_test, y_test = create_sequences(test_processed, features, target, seq_len)

    model = build_transformer_binary(seq_len, len(features))
    cbs = [EarlyStopping(patience=12, restore_best_weights=True), ReduceLROnPlateau(patience=5, factor=0.5)]
    history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=cbs, verbose=1)
    plot_history(history, "Transformer Loss")
    y_prob = model.predict(X_test).ravel()
    evaluate_and_print(y_test, y_prob)
    return model, scaler, test_processed, features

def train_tabnet_hybrid_pipeline(seq_len=SEQ_LENGTH):
    train_df, test_df, features, target = load_and_prepare_data()
    train_balanced, test_processed, scaler = preprocess_and_balance(train_df, test_df, features, target)

    X_train_seq, y_train = create_sequences(train_balanced, features, target, seq_len)
    X_test_seq, y_test = create_sequences(test_processed, features, target, seq_len)

    # For tabular branch we use the last day's features as tabular input
    X_train_tab = X_train_seq[:, -1, :]
    X_test_tab = X_test_seq[:, -1, :]

    model = build_tabnet_hybrid(seq_len, len(features))
    # compute class weights from original train (before SMOTE)
    orig_train_df = pd.concat([train_df for train_df in [train_df]], ignore_index=False)  # placeholder to keep same var name
    # compute class weights from y_train (balanced training after SMOTE not appropriate for weighting)
    cw_vals = compute_class_weight("balanced", classes=np.array([0,1]), y=y_train)
    class_weights = {0: cw_vals[0], 1: cw_vals[1]}

    cbs = [EarlyStopping(patience=12, restore_best_weights=True), ReduceLROnPlateau(patience=5, factor=0.5)]
    history = model.fit([X_train_seq, X_train_tab], y_train, epochs=EPOCHS, batch_size=BATCH_SIZE,
                        validation_split=0.2, callbacks=cbs, class_weight=class_weights, verbose=1)
    plot_history(history, "TabNet+Seq Loss")
    y_prob = model.predict([X_test_seq, X_test_tab]).ravel()
    evaluate_and_print(y_test, y_prob)
    return model, scaler, test_processed, features

# -----------------------------
# Main: choose which pipelines to run
# -----------------------------
if __name__ == "__main__":
    # Pick the model(s) you want to run. Running all three will take longer.

    print("Running CNN-LSTM pipeline...")
    model_cnn, scaler, test_processed, features = train_cnn_lstm_pipeline(seq_len=SEQ_LENGTH)
    X_test, y_test = create_sequences(test_processed, features, "Rain", SEQ_LENGTH)
    y_prob_cnn = model_cnn.predict(X_test).ravel()
    y_pred_cnn = (y_prob_cnn > 0.5).astype(int)

    print("\nRunning Transformer pipeline...")
    model_tr, scaler, test_processed, features = train_transformer_pipeline(seq_len=SEQ_LENGTH)
    X_test, y_test = create_sequences(test_processed, features, "Rain", SEQ_LENGTH)
    y_prob_tr = model_tr.predict(X_test).ravel()
    y_pred_tr = (y_prob_tr > 0.5).astype(int)

    print("\nRunning TabNet+Sequence pipeline...")
    model_tab, scaler, test_processed, features = train_tabnet_hybrid_pipeline(seq_len=SEQ_LENGTH)
    X_test, y_test = create_sequences(test_processed, features, "Rain", SEQ_LENGTH)
    y_prob_tab = model_tab.predict([X_test, X_test[:, -1, :]]).ravel()
    y_pred_tab = (y_prob_tab > 0.5).astype(int)
# Out:
# Running CNN-LSTM pipeline...
# TRAIN SIZE: 2161 TEST SIZE: 366
# Train class distribution:
#  Rain
# 1    0.532624
# 0    0.467376
# Name: proportion, dtype: float64
# After SMOTE balancing: Rain
# 0    1151
# 1    1151
# Name: count, dtype: int64
# Shapes: (2272, 30, 16) (2272,) (336, 30, 16) (336,)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 30, 64)         │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 30, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 15, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,737 (206.00 KB)
#  Trainable params: 52,737 (206.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6720 - auc: 0.7704 - loss: 0.6634 - precision: 0.6430 - recall: 0.8670 - val_accuracy: 0.6549 - val_auc: 0.8534 - val_loss: 0.6535 - val_precision: 0.5363 - val_recall: 0.8708 - learning_rate: 1.0000e-04
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7865 - auc: 0.8502 - loss: 0.5611 - precision: 0.7761 - recall: 0.8433 - val_accuracy: 0.7890 - val_auc: 0.8518 - val_loss: 0.5024 - val_precision: 0.7356 - val_recall: 0.7191 - learning_rate: 1.0000e-04
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8035 - auc: 0.8606 - loss: 0.4513 - precision: 0.8568 - recall: 0.7588 - val_accuracy: 0.7890 - val_auc: 0.8551 - val_loss: 0.4669 - val_precision: 0.7531 - val_recall: 0.6854 - learning_rate: 1.0000e-04
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8085 - auc: 0.8669 - loss: 0.4295 - precision: 0.8830 - recall: 0.7392 - val_accuracy: 0.7846 - val_auc: 0.8478 - val_loss: 0.4624 - val_precision: 0.7532 - val_recall: 0.6685 - learning_rate: 1.0000e-04
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8096 - auc: 0.8626 - loss: 0.4273 - precision: 0.8890 - recall: 0.7351 - val_accuracy: 0.7912 - val_auc: 0.8458 - val_loss: 0.4848 - val_precision: 0.7456 - val_recall: 0.7079 - learning_rate: 1.0000e-04
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8112 - auc: 0.8735 - loss: 0.4184 - precision: 0.8875 - recall: 0.7402 - val_accuracy: 0.7802 - val_auc: 0.8467 - val_loss: 0.4665 - val_precision: 0.7437 - val_recall: 0.6685 - learning_rate: 1.0000e-04
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8096 - auc: 0.8702 - loss: 0.4187 - precision: 0.8939 - recall: 0.7299 - val_accuracy: 0.7912 - val_auc: 0.8483 - val_loss: 0.4643 - val_precision: 0.7546 - val_recall: 0.6910 - learning_rate: 1.0000e-04
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8068 - auc: 0.8751 - loss: 0.4164 - precision: 0.8913 - recall: 0.7268 - val_accuracy: 0.7934 - val_auc: 0.8484 - val_loss: 0.5006 - val_precision: 0.7471 - val_recall: 0.7135 - learning_rate: 1.0000e-04
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8140 - auc: 0.8761 - loss: 0.4134 - precision: 0.9041 - recall: 0.7289 - val_accuracy: 0.7934 - val_auc: 0.8477 - val_loss: 0.4762 - val_precision: 0.7530 - val_recall: 0.7022 - learning_rate: 1.0000e-04
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8195 - auc: 0.8692 - loss: 0.4187 - precision: 0.9013 - recall: 0.7433 - val_accuracy: 0.7934 - val_auc: 0.8498 - val_loss: 0.4672 - val_precision: 0.7561 - val_recall: 0.6966 - learning_rate: 5.0000e-05
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8184 - auc: 0.8725 - loss: 0.4171 - precision: 0.9000 - recall: 0.7423 - val_accuracy: 0.7934 - val_auc: 0.8518 - val_loss: 0.4673 - val_precision: 0.7561 - val_recall: 0.6966 - learning_rate: 5.0000e-05
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8145 - auc: 0.8754 - loss: 0.4113 - precision: 0.9032 - recall: 0.7309 - val_accuracy: 0.7956 - val_auc: 0.8525 - val_loss: 0.4688 - val_precision: 0.7576 - val_recall: 0.7022 - learning_rate: 5.0000e-05
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8101 - auc: 0.8724 - loss: 0.4153 - precision: 0.8981 - recall: 0.7268 - val_accuracy: 0.7956 - val_auc: 0.8489 - val_loss: 0.4983 - val_precision: 0.7485 - val_recall: 0.7191 - learning_rate: 5.0000e-05
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8140 - auc: 0.8761 - loss: 0.4134 - precision: 0.8911 - recall: 0.7423 - val_accuracy: 0.7956 - val_auc: 0.8487 - val_loss: 0.4778 - val_precision: 0.7545 - val_recall: 0.7079 - learning_rate: 5.0000e-05
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8140 - auc: 0.8779 - loss: 0.4107 - precision: 0.8980 - recall: 0.7351 - val_accuracy: 0.7956 - val_auc: 0.8494 - val_loss: 0.4758 - val_precision: 0.7545 - val_recall: 0.7079 - learning_rate: 2.5000e-05
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8129 - auc: 0.8772 - loss: 0.4095 - precision: 0.8997 - recall: 0.7309 - val_accuracy: 0.7956 - val_auc: 0.8502 - val_loss: 0.4798 - val_precision: 0.7545 - val_recall: 0.7079 - learning_rate: 2.5000e-05
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Accuracy: 0.7708333333333334
# Precision: 0.9367088607594937
# Recall: 0.6883720930232559
# F1: 0.7935656836461126
# ROC-AUC: 0.8570055737074764
# Confusion matrix:
#  [[111  10]
#  [ 67 148]]
#               precision    recall  f1-score   support
#
#            0     0.6236    0.9174    0.7425       121
#            1     0.9367    0.6884    0.7936       215
#
#     accuracy                         0.7708       336
#    macro avg     0.7802    0.8029    0.7680       336
# weighted avg     0.8240    0.7708    0.7752       336
#
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# Running Transformer pipeline...
# TRAIN SIZE: 2161 TEST SIZE: 366
# Train class distribution:
#  Rain
# 1    0.532624
# 0    0.467376
# Name: proportion, dtype: float64
# After SMOTE balancing: Rain
# 0    1151
# 1    1151
# Name: count, dtype: int64
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 30, 16)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 30, 128)   │      2,176 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 30, 128)   │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 128)   │     66,048 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 30, 128)   │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 30, 128)   │          0 │ add[0][0],        │
# │                     │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 30, 128)   │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 30, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 30, 128)   │     32,896 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 30, 128)   │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 30, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 128)   │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 30, 128)   │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 30, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 30, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 30, 128)   │     32,896 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 30, 128)   │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 30, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │     16,512 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1)         │        129 │ dropout_7[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 283,777 (1.08 MB)
#  Trainable params: 283,777 (1.08 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7248 - auc_1: 0.7990 - loss: 0.5767 - precision_1: 0.7268 - recall_1: 0.7763 - val_accuracy: 0.7560 - val_auc_1: 0.8420 - val_loss: 0.5692 - val_precision_1: 0.6438 - val_recall_1: 0.8427 - learning_rate: 1.0000e-04
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7865 - auc_1: 0.8554 - loss: 0.4758 - precision_1: 0.7982 - recall_1: 0.8031 - val_accuracy: 0.7780 - val_auc_1: 0.8420 - val_loss: 0.4626 - val_precision_1: 0.7278 - val_recall_1: 0.6910 - learning_rate: 1.0000e-04
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7953 - auc_1: 0.8635 - loss: 0.4518 - precision_1: 0.8300 - recall_1: 0.7753 - val_accuracy: 0.7802 - val_auc_1: 0.8406 - val_loss: 0.4708 - val_precision_1: 0.7294 - val_recall_1: 0.6966 - learning_rate: 1.0000e-04
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7958 - auc_1: 0.8669 - loss: 0.4390 - precision_1: 0.8354 - recall_1: 0.7691 - val_accuracy: 0.7802 - val_auc_1: 0.8382 - val_loss: 0.4860 - val_precision_1: 0.7267 - val_recall_1: 0.7022 - learning_rate: 1.0000e-04
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8090 - auc_1: 0.8634 - loss: 0.4376 - precision_1: 0.8626 - recall_1: 0.7639 - val_accuracy: 0.7802 - val_auc_1: 0.8388 - val_loss: 0.4732 - val_precision_1: 0.7378 - val_recall_1: 0.6798 - learning_rate: 1.0000e-04
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8057 - auc_1: 0.8691 - loss: 0.4305 - precision_1: 0.8634 - recall_1: 0.7557 - val_accuracy: 0.7868 - val_auc_1: 0.8353 - val_loss: 0.4917 - val_precision_1: 0.7425 - val_recall_1: 0.6966 - learning_rate: 1.0000e-04
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8068 - auc_1: 0.8669 - loss: 0.4256 - precision_1: 0.8761 - recall_1: 0.7433 - val_accuracy: 0.8044 - val_auc_1: 0.8402 - val_loss: 0.4587 - val_precision_1: 0.7987 - val_recall_1: 0.6685 - learning_rate: 1.0000e-04
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8096 - auc_1: 0.8724 - loss: 0.4205 - precision_1: 0.8949 - recall_1: 0.7289 - val_accuracy: 0.7802 - val_auc_1: 0.8395 - val_loss: 0.4858 - val_precision_1: 0.7437 - val_recall_1: 0.6685 - learning_rate: 1.0000e-04
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8123 - auc_1: 0.8735 - loss: 0.4183 - precision_1: 0.8859 - recall_1: 0.7443 - val_accuracy: 0.7890 - val_auc_1: 0.8425 - val_loss: 0.5234 - val_precision_1: 0.7440 - val_recall_1: 0.7022 - learning_rate: 1.0000e-04
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8134 - auc_1: 0.8789 - loss: 0.4086 - precision_1: 0.9040 - recall_1: 0.7278 - val_accuracy: 0.7802 - val_auc_1: 0.8425 - val_loss: 0.4992 - val_precision_1: 0.7407 - val_recall_1: 0.6742 - learning_rate: 1.0000e-04
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8118 - auc_1: 0.8762 - loss: 0.4099 - precision_1: 0.9005 - recall_1: 0.7278 - val_accuracy: 0.7868 - val_auc_1: 0.8436 - val_loss: 0.4805 - val_precision_1: 0.7580 - val_recall_1: 0.6685 - learning_rate: 1.0000e-04
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8145 - auc_1: 0.8735 - loss: 0.4162 - precision_1: 0.8991 - recall_1: 0.7351 - val_accuracy: 0.7934 - val_auc_1: 0.8440 - val_loss: 0.5149 - val_precision_1: 0.7500 - val_recall_1: 0.7079 - learning_rate: 1.0000e-04
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8096 - auc_1: 0.8775 - loss: 0.4093 - precision_1: 0.8900 - recall_1: 0.7340 - val_accuracy: 0.7934 - val_auc_1: 0.8437 - val_loss: 0.4998 - val_precision_1: 0.7500 - val_recall_1: 0.7079 - learning_rate: 5.0000e-05
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8184 - auc_1: 0.8785 - loss: 0.4088 - precision_1: 0.8970 - recall_1: 0.7454 - val_accuracy: 0.7934 - val_auc_1: 0.8434 - val_loss: 0.5002 - val_precision_1: 0.7530 - val_recall_1: 0.7022 - learning_rate: 5.0000e-05
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8134 - auc_1: 0.8799 - loss: 0.4080 - precision_1: 0.8919 - recall_1: 0.7402 - val_accuracy: 0.7912 - val_auc_1: 0.8427 - val_loss: 0.5180 - val_precision_1: 0.7485 - val_recall_1: 0.7022 - learning_rate: 5.0000e-05
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8178 - auc_1: 0.8792 - loss: 0.4067 - precision_1: 0.9019 - recall_1: 0.7392 - val_accuracy: 0.7890 - val_auc_1: 0.8426 - val_loss: 0.5093 - val_precision_1: 0.7470 - val_recall_1: 0.6966 - learning_rate: 5.0000e-05
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8096 - auc_1: 0.8801 - loss: 0.4049 - precision_1: 0.8920 - recall_1: 0.7320 - val_accuracy: 0.7934 - val_auc_1: 0.8425 - val_loss: 0.5028 - val_precision_1: 0.7530 - val_recall_1: 0.7022 - learning_rate: 5.0000e-05
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8145 - auc_1: 0.8811 - loss: 0.4049 - precision_1: 0.8951 - recall_1: 0.7392 - val_accuracy: 0.7912 - val_auc_1: 0.8426 - val_loss: 0.4989 - val_precision_1: 0.7515 - val_recall_1: 0.6966 - learning_rate: 2.5000e-05
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8134 - auc_1: 0.8820 - loss: 0.4026 - precision_1: 0.8919 - recall_1: 0.7402 - val_accuracy: 0.7912 - val_auc_1: 0.8425 - val_loss: 0.4903 - val_precision_1: 0.7546 - val_recall_1: 0.6910 - learning_rate: 2.5000e-05
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Accuracy: 0.7410714285714286
# Precision: 0.9444444444444444
# Recall: 0.6325581395348837
# F1: 0.7576601671309192
# ROC-AUC: 0.8596578896790313
# Confusion matrix:
#  [[113   8]
#  [ 79 136]]
#               precision    recall  f1-score   support
#
#            0     0.5885    0.9339    0.7220       121
#            1     0.9444    0.6326    0.7577       215
#
#     accuracy                         0.7411       336
#    macro avg     0.7665    0.7832    0.7399       336
# weighted avg     0.8163    0.7411    0.7448       336
#
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# Running TabNet+Sequence pipeline...
# TRAIN SIZE: 2161 TEST SIZE: 366
# Train class distribution:
#  Rain
# 1    0.532624
# 0    0.467376
# Name: proportion, dtype: float64
# After SMOTE balancing: Rain
# 0    1151
# 1    1151
# Name: count, dtype: int64
# WARNING:tensorflow:From c:\Users\priya\miniconda3\envs\rainfall\lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 16)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 16)        │          0 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 16)        │        272 │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 16)        │          0 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 16)        │          0 │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 16)        │          0 │ lambda[0][0],     │
# │ (Multiply)          │                   │            │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 16)        │        272 │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 16)        │          0 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 16)        │          0 │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 16)        │          0 │ multiply_1[0][0], │
# │ (Multiply)          │                   │            │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 16)        │        272 │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 16)        │          0 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 16)        │          0 │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 16)        │          0 │ multiply_3[0][0], │
# │ (Multiply)          │                   │            │ lambda_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 16)        │        272 │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 30, 16)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 16)        │          0 │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 30, 32)    │      1,568 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 16)        │          0 │ input_layer_3[0]… │
# │                     │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 16)        │          0 │ input_layer_3[0]… │
# │ (Multiply)          │                   │            │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 16)        │          0 │ input_layer_3[0]… │
# │ (Multiply)          │                   │            │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 16)        │          0 │ input_layer_3[0]… │
# │ (Multiply)          │                   │            │ lambda_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 15, 32)    │          0 │ conv1d_2[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 64)        │      1,088 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 64)        │      1,088 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 64)        │      1,088 │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 64)        │      1,088 │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru (GRU)           │ (None, 64)        │     18,816 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 32)        │      2,080 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 32)        │      2,080 │ dense_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 32)        │      2,080 │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 32)        │      2,080 │ dense_20[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │      4,160 │ gru[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 32)        │          0 │ dense_12[0][0],   │
# │                     │                   │            │ dense_15[0][0],   │
# │                     │                   │            │ dense_18[0][0],   │
# │                     │                   │            │ dense_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 96)        │          0 │ dense_9[0][0],    │
# │ (Concatenate)       │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 64)        │      6,208 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64)        │          0 │ dense_22[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 1)         │         65 │ dropout_8[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 44,577 (174.13 KB)
#  Trainable params: 44,577 (174.13 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.7760 - auc_2: 0.8445 - loss: 0.4982 - precision_2: 0.8247 - recall_2: 0.7371 - val_accuracy: 0.7956 - val_auc_2: 0.8616 - val_loss: 0.4753 - val_precision_2: 0.7485 - val_recall_2: 0.7191 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8184 - auc_2: 0.8839 - loss: 0.4087 - precision_2: 0.8865 - recall_2: 0.7567 - val_accuracy: 0.8110 - val_auc_2: 0.8789 - val_loss: 0.4418 - val_precision_2: 0.8194 - val_recall_2: 0.6629 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8222 - auc_2: 0.8954 - loss: 0.3919 - precision_2: 0.8921 - recall_2: 0.7588 - val_accuracy: 0.8066 - val_auc_2: 0.8799 - val_loss: 0.4665 - val_precision_2: 0.7473 - val_recall_2: 0.7640 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8299 - auc_2: 0.9020 - loss: 0.3812 - precision_2: 0.8930 - recall_2: 0.7742 - val_accuracy: 0.7846 - val_auc_2: 0.8866 - val_loss: 0.4743 - val_precision_2: 0.6980 - val_recall_2: 0.7921 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8305 - auc_2: 0.9131 - loss: 0.3658 - precision_2: 0.8805 - recall_2: 0.7897 - val_accuracy: 0.8022 - val_auc_2: 0.8925 - val_loss: 0.4074 - val_precision_2: 0.7651 - val_recall_2: 0.7135 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8476 - auc_2: 0.9230 - loss: 0.3491 - precision_2: 0.8969 - recall_2: 0.8072 - val_accuracy: 0.7802 - val_auc_2: 0.8938 - val_loss: 0.4429 - val_precision_2: 0.6822 - val_recall_2: 0.8202 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8448 - auc_2: 0.9222 - loss: 0.3493 - precision_2: 0.8747 - recall_2: 0.8278 - val_accuracy: 0.8044 - val_auc_2: 0.8957 - val_loss: 0.4009 - val_precision_2: 0.7214 - val_recall_2: 0.8146 - learning_rate: 0.0010
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8470 - auc_2: 0.9247 - loss: 0.3429 - precision_2: 0.8761 - recall_2: 0.8309 - val_accuracy: 0.7692 - val_auc_2: 0.8946 - val_loss: 0.4504 - val_precision_2: 0.6622 - val_recall_2: 0.8371 - learning_rate: 0.0010
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8542 - auc_2: 0.9312 - loss: 0.3283 - precision_2: 0.8861 - recall_2: 0.8340 - val_accuracy: 0.7692 - val_auc_2: 0.8965 - val_loss: 0.4615 - val_precision_2: 0.6527 - val_recall_2: 0.8764 - learning_rate: 0.0010
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8663 - auc_2: 0.9390 - loss: 0.3116 - precision_2: 0.9052 - recall_2: 0.8371 - val_accuracy: 0.7846 - val_auc_2: 0.8974 - val_loss: 0.4261 - val_precision_2: 0.6852 - val_recall_2: 0.8315 - learning_rate: 0.0010
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8663 - auc_2: 0.9412 - loss: 0.3068 - precision_2: 0.8896 - recall_2: 0.8557 - val_accuracy: 0.7846 - val_auc_2: 0.8968 - val_loss: 0.4587 - val_precision_2: 0.6818 - val_recall_2: 0.8427 - learning_rate: 0.0010
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8696 - auc_2: 0.9429 - loss: 0.3023 - precision_2: 0.8887 - recall_2: 0.8639 - val_accuracy: 0.8066 - val_auc_2: 0.8873 - val_loss: 0.4161 - val_precision_2: 0.7586 - val_recall_2: 0.7416 - learning_rate: 0.0010
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8734 - auc_2: 0.9475 - loss: 0.2901 - precision_2: 0.8953 - recall_2: 0.8639 - val_accuracy: 0.7978 - val_auc_2: 0.8918 - val_loss: 0.4370 - val_precision_2: 0.7087 - val_recall_2: 0.8202 - learning_rate: 5.0000e-04
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8756 - auc_2: 0.9505 - loss: 0.2816 - precision_2: 0.8941 - recall_2: 0.8701 - val_accuracy: 0.7670 - val_auc_2: 0.8884 - val_loss: 0.4753 - val_precision_2: 0.6636 - val_recall_2: 0.8202 - learning_rate: 5.0000e-04
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8795 - auc_2: 0.9510 - loss: 0.2800 - precision_2: 0.9025 - recall_2: 0.8680 - val_accuracy: 0.7846 - val_auc_2: 0.8874 - val_loss: 0.4574 - val_precision_2: 0.6942 - val_recall_2: 0.8034 - learning_rate: 5.0000e-04
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8839 - auc_2: 0.9513 - loss: 0.2776 - precision_2: 0.9059 - recall_2: 0.8732 - val_accuracy: 0.7934 - val_auc_2: 0.8862 - val_loss: 0.4522 - val_precision_2: 0.7211 - val_recall_2: 0.7697 - learning_rate: 5.0000e-04
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8762 - auc_2: 0.9509 - loss: 0.2797 - precision_2: 0.8984 - recall_2: 0.8660 - val_accuracy: 0.7802 - val_auc_2: 0.8880 - val_loss: 0.4900 - val_precision_2: 0.6857 - val_recall_2: 0.8090 - learning_rate: 5.0000e-04
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8844 - auc_2: 0.9534 - loss: 0.2723 - precision_2: 0.9008 - recall_2: 0.8804 - val_accuracy: 0.7560 - val_auc_2: 0.8821 - val_loss: 0.5126 - val_precision_2: 0.6502 - val_recall_2: 0.8146 - learning_rate: 2.5000e-04
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8850 - auc_2: 0.9561 - loss: 0.2652 - precision_2: 0.9052 - recall_2: 0.8763 - val_accuracy: 0.7582 - val_auc_2: 0.8817 - val_loss: 0.5091 - val_precision_2: 0.6532 - val_recall_2: 0.8146 - learning_rate: 2.5000e-04
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# Accuracy: 0.8333333333333334
# Precision: 0.8916256157635468
# Recall: 0.8418604651162791
# F1: 0.8660287081339713
# ROC-AUC: 0.9068229867384201
# Confusion matrix:
#  [[ 99  22]
#  [ 34 181]]
#               precision    recall  f1-score   support
#
#            0     0.7444    0.8182    0.7795       121
#            1     0.8916    0.8419    0.8660       215
#
#     accuracy                         0.8333       336
#    macro avg     0.8180    0.8300    0.8228       336
# weighted avg     0.8386    0.8333    0.8349       336
#
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Number of points to display
N = 150  

plt.figure(figsize=(16, 6))

# Plot Actual
plt.plot(y_test[:N], 'ko-', label="Actual", linewidth=2, markersize=4, alpha=0.9)

# Plot CNN-LSTM Predictions
plt.plot(y_pred_cnn[:N], 'r--', label="CNN-LSTM Prediction", linewidth=1.8, alpha=0.8)

# Plot Transformer Predictions
plt.plot(y_pred_tr[:N], 'b-.', label="Transformer Based Binary Classifier Prediction", linewidth=1.8, alpha=0.8)

# Plot TabNet+Sequence Predictions
plt.plot(y_pred_tab[:N], 'g:', label="TabNet+(GRU-CNN)Sequence Hybrid Prediction", linewidth=2.2, alpha=0.9)

# Graph formatting
plt.title("Adilabad – Actual vs Predicted Rainfall (All Models)", fontsize=14)
plt.xlabel("Time Steps", fontsize=12)
plt.ylabel("Rain (1) / No Rain (0)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# --------------------------
# COLLECT METRICS FOR MODELS
# --------------------------

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

metrics = {}

def compute_metrics(y_true, y_prob):
    y_pred = (y_prob > 0.5).astype(int)
    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1": f1_score(y_true, y_pred),
        "ROC-AUC": roc_auc_score(y_true, y_prob)
    }

metrics["CNN-LSTM"] = compute_metrics(y_test, y_prob_cnn)
metrics["Transformer"] = compute_metrics(y_test, y_prob_tr)
metrics["TabNet+Seq(GRU+CNN)"] = compute_metrics(y_test, y_prob_tab)

print("\nCollected Metrics:")
metrics
# Out:
# Collected Metrics:
# {'CNN-LSTM': {'Accuracy': 0.7797619047619048,
#   'Precision': 0.937888198757764,
#   'Recall': 0.7023255813953488,
#   'F1': 0.8031914893617021,
#   'ROC-AUC': 0.8578896790313281},
#  'Transformer': {'Accuracy': 0.7857142857142857,
#   'Precision': 0.9386503067484663,
#   'Recall': 0.7116279069767442,
#   'F1': 0.8095238095238095,
#   'ROC-AUC': 0.8525850470882184},
#  'TabNet+Seq(GRU+CNN)': {'Accuracy': 0.8214285714285714,
#   'Precision': 0.9281767955801105,
#   'Recall': 0.7813953488372093,
#   'F1': 0.8484848484848485,
#   'ROC-AUC': 0.910128771862387}}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Metrics in order
metric_names = ["Accuracy", "Precision", "Recall", "F1", "ROC-AUC"]

# Model names
model_names = list(metrics.keys())

# Create matrix of metric values
values = np.array([[metrics[m][metric] * 100 for metric in metric_names] for m in model_names])

# Plot
plt.figure(figsize=(16, 8))

x = np.arange(len(metric_names))
width = 0.25  # bar width

# Colors
colors = ["#4C72B0", "#55A868", "#C44E52"]

for i, model in enumerate(model_names):
    plt.bar(x + i * width, values[i], width, label=model, color=colors[i], alpha=0.85)
    # Add value labels above bars
    for j, val in enumerate(values[i]):
        plt.text(x[j] + i * width, val + 0.3, f"{val:.2f}", ha='center', fontsize=10)

plt.xticks(x + width, metric_names, fontsize=12)
plt.ylabel("Percentage (%)", fontsize=14)
plt.title("Adilabad Model Comparison: CNN-LSTM vs Transformer vs TabNet+Seq(GRU+CNN)", fontsize=16)
plt.legend(fontsize=12,loc='lower left')
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.show()
