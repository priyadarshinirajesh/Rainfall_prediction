# %%
# rainfall_models_adilabad.py
# Three pipelines (CNN-LSTM, Transformer, TabNet+Sequence) sharing the same preprocessing.
# Author: (adapted for your request)
# in this, i have added more lag features (lag14, lag30) - helps in focusing on large monthly seasonal cycle

import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, roc_auc_score, roc_curve, auc
)
from sklearn.utils.class_weight import compute_class_weight
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# -----------------------------
# Config (change as needed)
# -----------------------------
DATA_FILES = {
    2019: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2019.csv",
    2020: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2020.csv",
    2021: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2021.csv",
    2022: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2022.csv",
    2023: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2023.csv",
    2024: r"C:\Users\priya\rainfall_prediction\Rainfall_prediction\datasets\adilabad_2024.csv",
}
TRAIN_YEARS = [2019, 2020, 2021,2022,2023]  #, 2022, 2023
TEST_YEAR = 2024
SEQ_LENGTH = 30       # sliding window length (you can increase to 30/60 to see effects)
BATCH_SIZE = 32
EPOCHS = 100
RANDOM_STATE = 42

# -----------------------------
# Utility: load + prepare dataset
# -----------------------------
def load_and_prepare_data(file_map=DATA_FILES):
    # load all csvs listed in file_map (keys = year)
    dfs = []
    for year in sorted(file_map.keys()):
        path = file_map[year]
        df = pd.read_csv(path).assign(YEAR=year)
        dfs.append(df)
    full_df = pd.concat(dfs, ignore_index=True)

    # required columns check (match your earlier code)
    required_cols = ['YEAR', 'MO', 'DY', 'PRECTOTCORR']
    missing = [c for c in required_cols if c not in full_df.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    # ensure numeric
    for c in required_cols:
        full_df[c] = pd.to_numeric(full_df[c], errors='coerce')
    full_df.dropna(subset=required_cols, inplace=True)

    # datetime and cyclic DOY features
    full_df['datetime'] = pd.to_datetime(dict(year=full_df['YEAR'], month=full_df['MO'], day=full_df['DY']))
    full_df['DOY'] = full_df['datetime'].dt.dayofyear
    full_df['sin_DOY'] = np.sin(2*np.pi*full_df['DOY']/365.25)
    full_df['cos_DOY'] = np.cos(2*np.pi*full_df['DOY']/365.25)

    # lags
    for lag in [1, 3, 7, 14, 30]:
        full_df[f'PRECTOTCORR_lag{lag}'] = full_df['PRECTOTCORR'].shift(lag)

    # sea level temp: adilabad elev = 264m (your formula)
    full_df['SLT'] = full_df['TS'] + (0.0065 * 264)

    # drop any remaining NaNs
    full_df.dropna(inplace=True)

    # features and target (binary)
    features = ['SLT', 'SLP', 'T2M', 'TS', 'T2M_MAX', 'T2M_MIN',
            'RH2M', 'WS10M_MAX', 'WS10M_MIN',
            'sin_DOY', 'cos_DOY',
            'PRECTOTCORR_lag1', 'PRECTOTCORR_lag3', 'PRECTOTCORR_lag7',
            'PRECTOTCORR_lag14', 'PRECTOTCORR_lag30']

    full_df['Rain'] = (full_df['PRECTOTCORR'] > 0).astype(int)

    train_df = full_df[full_df['YEAR'].isin(TRAIN_YEARS)].copy()
    test_df = full_df[full_df['YEAR'] == TEST_YEAR].copy()

    # temporal leakage check
    if len(train_df) == 0 or len(test_df) == 0:
        raise ValueError("Train or test data empty. Check years and files.")
    if test_df['datetime'].min() <= train_df['datetime'].max():
        # Typically okay as long as test is separate year; still keep check
        pass

    print("TRAIN SIZE:", len(train_df), "TEST SIZE:", len(test_df))
    print("Train class distribution:\n", train_df['Rain'].value_counts(normalize=True))
    return train_df, test_df, features, 'Rain'

# -----------------------------
# Preprocess: scaling + SMOTE + sequences
# -----------------------------
def preprocess_and_balance(train_df, test_df, features, target):
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(train_df[features])
    X_test_scaled = scaler.transform(test_df[features])

    # SMOTE on training data (tabular)
    sm = SMOTE(random_state=RANDOM_STATE)
    X_res, y_res = sm.fit_resample(X_train_scaled, train_df[target].values)

    # create balanced train DataFrame (ordered by resample index -> shuffled)
    train_balanced = pd.DataFrame(X_res, columns=features)
    train_balanced[target] = y_res

    test_processed = pd.DataFrame(X_test_scaled, columns=features, index=test_df.index)
    test_processed[target] = test_df[target].values
    test_processed['DOY'] = test_df['DOY']

    print("After SMOTE balancing:", train_balanced[target].value_counts())
    return train_balanced, test_processed, scaler

def create_sequences(data_df, features, target, seq_length):
    X, y = [], []
    for i in range(len(data_df) - seq_length):
        X.append(data_df[features].iloc[i:i+seq_length].values)
        y.append(data_df[target].iloc[i+seq_length])
    X = np.array(X)
    y = np.array(y)
    return X, y

# -----------------------------
# Model A: CNN-LSTM
# -----------------------------
def build_cnn_lstm(seq_len, n_features):
    inp = Input(shape=(seq_len, n_features))
    x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(inp)
    x = Conv1D(64, kernel_size=3, padding='same', activation='relu')(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = LSTM(64)(x)
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.3)(x)
    out = Dense(1, activation='sigmoid')(x)
    model = Model(inp, out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    model.summary()
    return model

# -----------------------------
# Model B: Transformer (simple encoder)
# -----------------------------
def build_transformer_binary(seq_len, n_features, d_model=128, heads=4, ff_dim=256):
    inp = Input(shape=(seq_len, n_features))
    # linear projection to d_model
    x = Dense(d_model)(inp)
    # learnable positional embedding
    pos_emb = tf.Variable(tf.random.normal([1, seq_len, d_model]), trainable=True)
    x = x + pos_emb

    for _ in range(2):  # two encoder blocks
        attn = MultiHeadAttention(num_heads=heads, key_dim=d_model//heads)(x, x)
        attn = Dropout(0.2)(attn)
        x = LayerNormalization()(x + attn)

        ffn = Dense(ff_dim, activation='relu')(x)
        ffn = Dense(d_model)(ffn)
        ffn = Dropout(0.2)(ffn)
        x = LayerNormalization()(x + ffn)

    x = GlobalAveragePooling1D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)
    out = Dense(1, activation='sigmoid')(x)
    model = Model(inp, out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    model.summary()
    return model

# -----------------------------
# Model C: TabNet + Sequence hybrid (custom sparsemax implemented)
# -----------------------------
def sparsemax(logits, axis=-1):
    logits = tf.cast(logits, tf.float32)
    z = tf.sort(logits, direction='DESCENDING', axis=axis)
    z_cumsum = tf.cumsum(z, axis=axis)
    k = tf.range(1, tf.shape(z)[-1] + 1, dtype=tf.float32)
    k_shape = [1] * (len(logits.shape) - 1) + [-1]
    k = tf.reshape(k, k_shape)
    support = tf.cast(1 + k * z > z_cumsum, tf.float32)
    k_z = tf.reduce_sum(support, axis=axis, keepdims=True)
    tau = (tf.reduce_sum(z * support, axis=axis, keepdims=True) - 1.0) / k_z
    return tf.maximum(0.0, logits - tau)

def tabnet_block(inputs, input_dim, feature_dim=64, output_dim=32, steps=4, gamma=1.5):

    # Prior initialized as ones but using a Lambda layer
    prior = Lambda(lambda x: tf.ones_like(x))(inputs)

    outputs = []

    for i in range(steps):

        # Step 1: Attentive transformer (Mask)
        mask_logits = Dense(input_dim)(prior)
        
        # sparsemax using Lambda so Keras accepts it
        mask = Lambda(lambda x: sparsemax(x))(mask_logits)

        # masked inputs
        masked_data = Multiply()([inputs, mask])

        # Step 2: Feature transformer
        feat = Dense(feature_dim, activation="relu")(masked_data)
        feat = Dense(output_dim, activation="relu")(feat)

        outputs.append(feat)

        # Update prior = prior * (gamma - mask)
        prior = Multiply()([prior, Lambda(lambda x: gamma - x)(mask)])

    # Combine outputs
    out = Add()(outputs)  
    return out


def sequence_branch(seq_inp, hidden=64):
    # small CNN+GRU branch
    x = Conv1D(32, 3, padding='same', activation='relu')(seq_inp)
    x = MaxPooling1D(2)(x)
    x = GRU(hidden, return_sequences=False)(x)
    x = Dense(64, activation='relu')(x)
    return x

def build_tabnet_hybrid(seq_len, n_features, tab_feature_dim=64, tab_output_dim=32, seq_hidden=64):
    seq_inp = Input(shape=(seq_len, n_features))
    tab_inp = Input(shape=(n_features,))

    seq_out = sequence_branch(seq_inp, hidden=seq_hidden)
    tab_out = tabnet_block(tab_inp, input_dim=n_features, feature_dim=tab_feature_dim, output_dim=tab_output_dim, steps=4)

    merged = Concatenate()([seq_out, tab_out])
    x = Dense(64, activation='relu')(merged)
    x = Dropout(0.3)(x)
    out = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=[seq_inp, tab_inp], outputs=out)
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3),
                  loss='binary_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.AUC()])
    model.summary()
    return model

# -----------------------------
# Training + evaluation helpers
# -----------------------------
def plot_history(history, title="Training"):
    plt.figure(figsize=(10,4))
    plt.plot(history.history['loss'], label='train loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='val loss')
    plt.title(title)
    plt.legend()
    plt.show()

def evaluate_and_print(y_true, y_prob):
    y_pred = (y_prob > 0.5).astype(int).ravel()
    print("Accuracy:", accuracy_score(y_true, y_pred))
    print("Precision:", precision_score(y_true, y_pred))
    print("Recall:", recall_score(y_true, y_pred))
    print("F1:", f1_score(y_true, y_pred))
    print("ROC-AUC:", roc_auc_score(y_true, y_prob))
    print("Confusion matrix:\n", confusion_matrix(y_true, y_pred))
    print(classification_report(y_true, y_pred, digits=4))

# -----------------------------
# End-to-end train functions
# -----------------------------
def train_cnn_lstm_pipeline(seq_len=SEQ_LENGTH):
    train_df, test_df, features, target = load_and_prepare_data()
    train_balanced, test_processed, scaler = preprocess_and_balance(train_df, test_df, features, target)

    X_train, y_train = create_sequences(train_balanced, features, target, seq_len)
    X_test, y_test = create_sequences(test_processed, features, target, seq_len)

    print("Shapes:", X_train.shape, y_train.shape, X_test.shape, y_test.shape)
    model = build_cnn_lstm(seq_len, len(features))
    cbs = [EarlyStopping(patience=12, restore_best_weights=True), ReduceLROnPlateau(patience=5, factor=0.5)]
    history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=cbs, verbose=1)
    plot_history(history, "CNN-LSTM Loss")
    y_prob = model.predict(X_test).ravel()
    evaluate_and_print(y_test, y_prob)
    return model, scaler, test_processed, features

def train_transformer_pipeline(seq_len=SEQ_LENGTH):
    train_df, test_df, features, target = load_and_prepare_data()
    train_balanced, test_processed, scaler = preprocess_and_balance(train_df, test_df, features, target)

    X_train, y_train = create_sequences(train_balanced, features, target, seq_len)
    X_test, y_test = create_sequences(test_processed, features, target, seq_len)

    model = build_transformer_binary(seq_len, len(features))
    cbs = [EarlyStopping(patience=12, restore_best_weights=True), ReduceLROnPlateau(patience=5, factor=0.5)]
    history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2, callbacks=cbs, verbose=1)
    plot_history(history, "Transformer Loss")
    y_prob = model.predict(X_test).ravel()
    evaluate_and_print(y_test, y_prob)
    return model, scaler, test_processed, features

def train_tabnet_hybrid_pipeline(seq_len=SEQ_LENGTH):
    train_df, test_df, features, target = load_and_prepare_data()
    train_balanced, test_processed, scaler = preprocess_and_balance(train_df, test_df, features, target)

    X_train_seq, y_train = create_sequences(train_balanced, features, target, seq_len)
    X_test_seq, y_test = create_sequences(test_processed, features, target, seq_len)

    # For tabular branch we use the last day's features as tabular input
    X_train_tab = X_train_seq[:, -1, :]
    X_test_tab = X_test_seq[:, -1, :]

    model = build_tabnet_hybrid(seq_len, len(features))
    # compute class weights from original train (before SMOTE)
    orig_train_df = pd.concat([train_df for train_df in [train_df]], ignore_index=False)  # placeholder to keep same var name
    # compute class weights from y_train (balanced training after SMOTE not appropriate for weighting)
    cw_vals = compute_class_weight("balanced", classes=np.array([0,1]), y=y_train)
    class_weights = {0: cw_vals[0], 1: cw_vals[1]}

    cbs = [EarlyStopping(patience=12, restore_best_weights=True), ReduceLROnPlateau(patience=5, factor=0.5)]
    history = model.fit([X_train_seq, X_train_tab], y_train, epochs=EPOCHS, batch_size=BATCH_SIZE,
                        validation_split=0.2, callbacks=cbs, class_weight=class_weights, verbose=1)
    plot_history(history, "TabNet+Seq Loss")
    y_prob = model.predict([X_test_seq, X_test_tab]).ravel()
    evaluate_and_print(y_test, y_prob)
    return model, scaler, test_processed, features

# -----------------------------
# Main: choose which pipelines to run
# -----------------------------
if __name__ == "__main__":
    # Pick the model(s) you want to run. Running all three will take longer.

    print("Running CNN-LSTM pipeline...")
    model_cnn, scaler, test_processed, features = train_cnn_lstm_pipeline(seq_len=SEQ_LENGTH)
    X_test, y_test = create_sequences(test_processed, features, "Rain", SEQ_LENGTH)
    y_prob_cnn = model_cnn.predict(X_test).ravel()
    y_pred_cnn = (y_prob_cnn > 0.5).astype(int)

    print("\nRunning Transformer pipeline...")
    model_tr, scaler, test_processed, features = train_transformer_pipeline(seq_len=SEQ_LENGTH)
    X_test, y_test = create_sequences(test_processed, features, "Rain", SEQ_LENGTH)
    y_prob_tr = model_tr.predict(X_test).ravel()
    y_pred_tr = (y_prob_tr > 0.5).astype(int)

    print("\nRunning TabNet+Sequence pipeline...")
    model_tab, scaler, test_processed, features = train_tabnet_hybrid_pipeline(seq_len=SEQ_LENGTH)
    X_test, y_test = create_sequences(test_processed, features, "Rain", SEQ_LENGTH)
    y_prob_tab = model_tab.predict([X_test, X_test[:, -1, :]]).ravel()
    y_pred_tab = (y_prob_tab > 0.5).astype(int)
# Out:
# Running CNN-LSTM pipeline...
# TRAIN SIZE: 2161 TEST SIZE: 366
# Train class distribution:
#  Rain
# 1    0.532624
# 0    0.467376
# Name: proportion, dtype: float64
# After SMOTE balancing: Rain
# 0    1151
# 1    1151
# Name: count, dtype: int64
# Shapes: (2272, 30, 16) (2272,) (336, 30, 16) (336,)
# Model: "functional_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_17 (InputLayer)     │ (None, 30, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 30, 64)         │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_15 (Conv1D)              │ (None, 30, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 15, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_98 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_37 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_99 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,737 (206.00 KB)
#  Trainable params: 52,737 (206.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6544 - auc_13: 0.7118 - loss: 0.6740 - precision_13: 0.6680 - recall_13: 0.7010 - val_accuracy: 0.6747 - val_auc_13: 0.8229 - val_loss: 0.6608 - val_precision_13: 0.5540 - val_recall_13: 0.8652 - learning_rate: 1.0000e-04
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7755 - auc_13: 0.8384 - loss: 0.5732 - precision_13: 0.7750 - recall_13: 0.8165 - val_accuracy: 0.8242 - val_auc_13: 0.8357 - val_loss: 0.5254 - val_precision_13: 0.7579 - val_recall_13: 0.8090 - learning_rate: 1.0000e-04
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7997 - auc_13: 0.8682 - loss: 0.4553 - precision_13: 0.8337 - recall_13: 0.7804 - val_accuracy: 0.7868 - val_auc_13: 0.8360 - val_loss: 0.4707 - val_precision_13: 0.7396 - val_recall_13: 0.7022 - learning_rate: 1.0000e-04
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8118 - auc_13: 0.8640 - loss: 0.4355 - precision_13: 0.8792 - recall_13: 0.7505 - val_accuracy: 0.7780 - val_auc_13: 0.8446 - val_loss: 0.4553 - val_precision_13: 0.7391 - val_recall_13: 0.6685 - learning_rate: 1.0000e-04
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8096 - auc_13: 0.8724 - loss: 0.4217 - precision_13: 0.8732 - recall_13: 0.7526 - val_accuracy: 0.7912 - val_auc_13: 0.8431 - val_loss: 0.4599 - val_precision_13: 0.7677 - val_recall_13: 0.6685 - learning_rate: 1.0000e-04
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8057 - auc_13: 0.8707 - loss: 0.4213 - precision_13: 0.8767 - recall_13: 0.7402 - val_accuracy: 0.7780 - val_auc_13: 0.8426 - val_loss: 0.4695 - val_precision_13: 0.7362 - val_recall_13: 0.6742 - learning_rate: 1.0000e-04
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8096 - auc_13: 0.8701 - loss: 0.4217 - precision_13: 0.8842 - recall_13: 0.7402 - val_accuracy: 0.7824 - val_auc_13: 0.8433 - val_loss: 0.4662 - val_precision_13: 0.7484 - val_recall_13: 0.6685 - learning_rate: 1.0000e-04
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8134 - auc_13: 0.8736 - loss: 0.4194 - precision_13: 0.8929 - recall_13: 0.7392 - val_accuracy: 0.7868 - val_auc_13: 0.8477 - val_loss: 0.4561 - val_precision_13: 0.7580 - val_recall_13: 0.6685 - learning_rate: 1.0000e-04
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8068 - auc_13: 0.8767 - loss: 0.4155 - precision_13: 0.8816 - recall_13: 0.7371 - val_accuracy: 0.7956 - val_auc_13: 0.8437 - val_loss: 0.5060 - val_precision_13: 0.7485 - val_recall_13: 0.7191 - learning_rate: 1.0000e-04
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8101 - auc_13: 0.8743 - loss: 0.4150 - precision_13: 0.8863 - recall_13: 0.7392 - val_accuracy: 0.7824 - val_auc_13: 0.8458 - val_loss: 0.4671 - val_precision_13: 0.7453 - val_recall_13: 0.6742 - learning_rate: 5.0000e-05
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8112 - auc_13: 0.8748 - loss: 0.4126 - precision_13: 0.8914 - recall_13: 0.7361 - val_accuracy: 0.7868 - val_auc_13: 0.8463 - val_loss: 0.4876 - val_precision_13: 0.7425 - val_recall_13: 0.6966 - learning_rate: 5.0000e-05
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8123 - auc_13: 0.8772 - loss: 0.4099 - precision_13: 0.8868 - recall_13: 0.7433 - val_accuracy: 0.7868 - val_auc_13: 0.8479 - val_loss: 0.4838 - val_precision_13: 0.7425 - val_recall_13: 0.6966 - learning_rate: 5.0000e-05
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8140 - auc_13: 0.8796 - loss: 0.4089 - precision_13: 0.8863 - recall_13: 0.7474 - val_accuracy: 0.7868 - val_auc_13: 0.8493 - val_loss: 0.4703 - val_precision_13: 0.7485 - val_recall_13: 0.6854 - learning_rate: 5.0000e-05
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8096 - auc_13: 0.8776 - loss: 0.4135 - precision_13: 0.8949 - recall_13: 0.7289 - val_accuracy: 0.7934 - val_auc_13: 0.8466 - val_loss: 0.4950 - val_precision_13: 0.7471 - val_recall_13: 0.7135 - learning_rate: 5.0000e-05
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8134 - auc_13: 0.8741 - loss: 0.4146 - precision_13: 0.8852 - recall_13: 0.7474 - val_accuracy: 0.7912 - val_auc_13: 0.8478 - val_loss: 0.4782 - val_precision_13: 0.7485 - val_recall_13: 0.7022 - learning_rate: 2.5000e-05
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8189 - auc_13: 0.8826 - loss: 0.4041 - precision_13: 0.8962 - recall_13: 0.7474 - val_accuracy: 0.7912 - val_auc_13: 0.8482 - val_loss: 0.4837 - val_precision_13: 0.7485 - val_recall_13: 0.7022 - learning_rate: 2.5000e-05
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Accuracy: 0.7797619047619048
# Precision: 0.937888198757764
# Recall: 0.7023255813953488
# F1: 0.8031914893617021
# ROC-AUC: 0.8578896790313281
# Confusion matrix:
#  [[111  10]
#  [ 64 151]]
#               precision    recall  f1-score   support
#
#            0     0.6343    0.9174    0.7500       121
#            1     0.9379    0.7023    0.8032       215
#
#     accuracy                         0.7798       336
#    macro avg     0.7861    0.8098    0.7766       336
# weighted avg     0.8286    0.7798    0.7840       336
#
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Running Transformer pipeline...
# TRAIN SIZE: 2161 TEST SIZE: 366
# Train class distribution:
#  Rain
# 1    0.532624
# 0    0.467376
# Name: proportion, dtype: float64
# After SMOTE balancing: Rain
# 0    1151
# 1    1151
# Name: count, dtype: int64
# Model: "functional_14"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_18      │ (None, 30, 16)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_100 (Dense)   │ (None, 30, 128)   │      2,176 │ input_layer_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 30, 128)   │          0 │ dense_100[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 128)   │     66,048 │ add_24[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_24[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_39          │ (None, 30, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 30, 128)   │          0 │ add_24[0][0],     │
# │                     │                   │            │ dropout_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_25[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_101 (Dense)   │ (None, 30, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_102 (Dense)   │ (None, 30, 128)   │     32,896 │ dense_101[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_40          │ (None, 30, 128)   │          0 │ dense_102[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 30, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_40[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_26[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 30, 128)   │     66,048 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_42          │ (None, 30, 128)   │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 30, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_42[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_27[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_103 (Dense)   │ (None, 30, 256)   │     33,024 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_104 (Dense)   │ (None, 30, 128)   │     32,896 │ dense_103[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_43          │ (None, 30, 128)   │          0 │ dense_104[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 30, 128)   │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_43[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 30, 128)   │        256 │ add_28[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_105 (Dense)   │ (None, 128)       │     16,512 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_44          │ (None, 128)       │          0 │ dense_105[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_106 (Dense)   │ (None, 1)         │        129 │ dropout_44[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 283,777 (1.08 MB)
#  Trainable params: 283,777 (1.08 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.7149 - auc_14: 0.7808 - loss: 0.5920 - precision_14: 0.7156 - recall_14: 0.7732 - val_accuracy: 0.8110 - val_auc_14: 0.8430 - val_loss: 0.5202 - val_precision_14: 0.7371 - val_recall_14: 0.8034 - learning_rate: 1.0000e-04
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8002 - auc_14: 0.8655 - loss: 0.4596 - precision_14: 0.8198 - recall_14: 0.8021 - val_accuracy: 0.7934 - val_auc_14: 0.8424 - val_loss: 0.4571 - val_precision_14: 0.7692 - val_recall_14: 0.6742 - learning_rate: 1.0000e-04
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8096 - auc_14: 0.8657 - loss: 0.4372 - precision_14: 0.8562 - recall_14: 0.7732 - val_accuracy: 0.7868 - val_auc_14: 0.8396 - val_loss: 0.4783 - val_precision_14: 0.7396 - val_recall_14: 0.7022 - learning_rate: 1.0000e-04
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8052 - auc_14: 0.8624 - loss: 0.4368 - precision_14: 0.8711 - recall_14: 0.7454 - val_accuracy: 0.7912 - val_auc_14: 0.8375 - val_loss: 0.5792 - val_precision_14: 0.7196 - val_recall_14: 0.7640 - learning_rate: 1.0000e-04
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8024 - auc_14: 0.8712 - loss: 0.4293 - precision_14: 0.8607 - recall_14: 0.7515 - val_accuracy: 0.7824 - val_auc_14: 0.8375 - val_loss: 0.4739 - val_precision_14: 0.7484 - val_recall_14: 0.6685 - learning_rate: 1.0000e-04
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8041 - auc_14: 0.8686 - loss: 0.4238 - precision_14: 0.8735 - recall_14: 0.7402 - val_accuracy: 0.8088 - val_auc_14: 0.8392 - val_loss: 0.4580 - val_precision_14: 0.8182 - val_recall_14: 0.6573 - learning_rate: 1.0000e-04
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8096 - auc_14: 0.8743 - loss: 0.4149 - precision_14: 0.8920 - recall_14: 0.7320 - val_accuracy: 0.7802 - val_auc_14: 0.8403 - val_loss: 0.4835 - val_precision_14: 0.7437 - val_recall_14: 0.6685 - learning_rate: 1.0000e-04
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8068 - auc_14: 0.8731 - loss: 0.4136 - precision_14: 0.8779 - recall_14: 0.7412 - val_accuracy: 0.7912 - val_auc_14: 0.8426 - val_loss: 0.4710 - val_precision_14: 0.7677 - val_recall_14: 0.6685 - learning_rate: 5.0000e-05
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.8112 - auc_14: 0.8760 - loss: 0.4110 - precision_14: 0.8885 - recall_14: 0.7392 - val_accuracy: 0.7846 - val_auc_14: 0.8418 - val_loss: 0.4793 - val_precision_14: 0.7532 - val_recall_14: 0.6685 - learning_rate: 5.0000e-05
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8085 - auc_14: 0.8760 - loss: 0.4123 - precision_14: 0.8868 - recall_14: 0.7351 - val_accuracy: 0.7890 - val_auc_14: 0.8427 - val_loss: 0.4774 - val_precision_14: 0.7628 - val_recall_14: 0.6685 - learning_rate: 5.0000e-05
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8079 - auc_14: 0.8727 - loss: 0.4119 - precision_14: 0.8857 - recall_14: 0.7351 - val_accuracy: 0.7846 - val_auc_14: 0.8423 - val_loss: 0.4883 - val_precision_14: 0.7532 - val_recall_14: 0.6685 - learning_rate: 5.0000e-05
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8107 - auc_14: 0.8718 - loss: 0.4118 - precision_14: 0.8992 - recall_14: 0.7268 - val_accuracy: 0.7846 - val_auc_14: 0.8437 - val_loss: 0.5001 - val_precision_14: 0.7439 - val_recall_14: 0.6854 - learning_rate: 5.0000e-05
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8112 - auc_14: 0.8745 - loss: 0.4120 - precision_14: 0.8866 - recall_14: 0.7412 - val_accuracy: 0.7912 - val_auc_14: 0.8431 - val_loss: 0.4743 - val_precision_14: 0.7677 - val_recall_14: 0.6685 - learning_rate: 2.5000e-05
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.8134 - auc_14: 0.8739 - loss: 0.4121 - precision_14: 0.8900 - recall_14: 0.7423 - val_accuracy: 0.7846 - val_auc_14: 0.8426 - val_loss: 0.5013 - val_precision_14: 0.7439 - val_recall_14: 0.6854 - learning_rate: 2.5000e-05
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# Accuracy: 0.7857142857142857
# Precision: 0.9386503067484663
# Recall: 0.7116279069767442
# F1: 0.8095238095238095
# ROC-AUC: 0.8525850470882184
# Confusion matrix:
#  [[111  10]
#  [ 62 153]]
#               precision    recall  f1-score   support
#
#            0     0.6416    0.9174    0.7551       121
#            1     0.9387    0.7116    0.8095       215
#
#     accuracy                         0.7857       336
#    macro avg     0.7901    0.8145    0.7823       336
# weighted avg     0.8317    0.7857    0.7899       336
#
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# Running TabNet+Sequence pipeline...
# TRAIN SIZE: 2161 TEST SIZE: 366
# Train class distribution:
#  Rain
# 1    0.532624
# 0    0.467376
# Name: proportion, dtype: float64
# After SMOTE balancing: Rain
# 0    1151
# 1    1151
# Name: count, dtype: int64
# Model: "functional_15"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_20      │ (None, 16)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_36 (Lambda)  │ (None, 16)        │          0 │ input_layer_20[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_108 (Dense)   │ (None, 16)        │        272 │ lambda_36[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_37 (Lambda)  │ (None, 16)        │          0 │ dense_108[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_38 (Lambda)  │ (None, 16)        │          0 │ lambda_37[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_33         │ (None, 16)        │          0 │ lambda_36[0][0],  │
# │ (Multiply)          │                   │            │ lambda_38[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_111 (Dense)   │ (None, 16)        │        272 │ multiply_33[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_39 (Lambda)  │ (None, 16)        │          0 │ dense_111[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_40 (Lambda)  │ (None, 16)        │          0 │ lambda_39[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_35         │ (None, 16)        │          0 │ multiply_33[0][0… │
# │ (Multiply)          │                   │            │ lambda_40[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_114 (Dense)   │ (None, 16)        │        272 │ multiply_35[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_41 (Lambda)  │ (None, 16)        │          0 │ dense_114[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_42 (Lambda)  │ (None, 16)        │          0 │ lambda_41[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_37         │ (None, 16)        │          0 │ multiply_35[0][0… │
# │ (Multiply)          │                   │            │ lambda_42[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_117 (Dense)   │ (None, 16)        │        272 │ multiply_37[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_19      │ (None, 30, 16)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_43 (Lambda)  │ (None, 16)        │          0 │ dense_117[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 30, 32)    │      1,568 │ input_layer_19[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_32         │ (None, 16)        │          0 │ input_layer_20[0… │
# │ (Multiply)          │                   │            │ lambda_37[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_34         │ (None, 16)        │          0 │ input_layer_20[0… │
# │ (Multiply)          │                   │            │ lambda_39[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_36         │ (None, 16)        │          0 │ input_layer_20[0… │
# │ (Multiply)          │                   │            │ lambda_41[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_38         │ (None, 16)        │          0 │ input_layer_20[0… │
# │ (Multiply)          │                   │            │ lambda_43[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_10    │ (None, 15, 32)    │          0 │ conv1d_16[0][0]   │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_109 (Dense)   │ (None, 64)        │      1,088 │ multiply_32[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_112 (Dense)   │ (None, 64)        │      1,088 │ multiply_34[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_115 (Dense)   │ (None, 64)        │      1,088 │ multiply_36[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_118 (Dense)   │ (None, 64)        │      1,088 │ multiply_38[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gru_4 (GRU)         │ (None, 64)        │     18,816 │ max_pooling1d_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_110 (Dense)   │ (None, 32)        │      2,080 │ dense_109[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_113 (Dense)   │ (None, 32)        │      2,080 │ dense_112[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_116 (Dense)   │ (None, 32)        │      2,080 │ dense_115[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_119 (Dense)   │ (None, 32)        │      2,080 │ dense_118[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_107 (Dense)   │ (None, 64)        │      4,160 │ gru_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 32)        │          0 │ dense_110[0][0],  │
# │                     │                   │            │ dense_113[0][0],  │
# │                     │                   │            │ dense_116[0][0],  │
# │                     │                   │            │ dense_119[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 96)        │          0 │ dense_107[0][0],  │
# │ (Concatenate)       │                   │            │ add_29[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_120 (Dense)   │ (None, 64)        │      6,208 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_45          │ (None, 64)        │          0 │ dense_120[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_121 (Dense)   │ (None, 1)         │         65 │ dropout_45[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 44,577 (174.13 KB)
#  Trainable params: 44,577 (174.13 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - accuracy: 0.7749 - auc_15: 0.8209 - loss: 0.5363 - precision_15: 0.8059 - recall_15: 0.7619 - val_accuracy: 0.8154 - val_auc_15: 0.8821 - val_loss: 0.5458 - val_precision_15: 0.7448 - val_recall_15: 0.8034 - learning_rate: 0.0010
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8134 - auc_15: 0.8716 - loss: 0.4245 - precision_15: 0.8769 - recall_15: 0.7567 - val_accuracy: 0.7978 - val_auc_15: 0.8882 - val_loss: 0.4398 - val_precision_15: 0.7654 - val_recall_15: 0.6966 - learning_rate: 0.0010
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8162 - auc_15: 0.8824 - loss: 0.4061 - precision_15: 0.8869 - recall_15: 0.7515 - val_accuracy: 0.8132 - val_auc_15: 0.8904 - val_loss: 0.4127 - val_precision_15: 0.8252 - val_recall_15: 0.6629 - learning_rate: 0.0010
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8239 - auc_15: 0.8935 - loss: 0.3948 - precision_15: 0.8916 - recall_15: 0.7629 - val_accuracy: 0.7912 - val_auc_15: 0.8943 - val_loss: 0.5503 - val_precision_15: 0.7150 - val_recall_15: 0.7753 - learning_rate: 0.0010
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8255 - auc_15: 0.8969 - loss: 0.3899 - precision_15: 0.8948 - recall_15: 0.7629 - val_accuracy: 0.8308 - val_auc_15: 0.9038 - val_loss: 0.3862 - val_precision_15: 0.8344 - val_recall_15: 0.7079 - learning_rate: 0.0010
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8272 - auc_15: 0.9069 - loss: 0.3762 - precision_15: 0.8971 - recall_15: 0.7639 - val_accuracy: 0.7956 - val_auc_15: 0.9077 - val_loss: 0.4343 - val_precision_15: 0.6977 - val_recall_15: 0.8427 - learning_rate: 0.0010
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8465 - auc_15: 0.9220 - loss: 0.3516 - precision_15: 0.8835 - recall_15: 0.8206 - val_accuracy: 0.8044 - val_auc_15: 0.9100 - val_loss: 0.4103 - val_precision_15: 0.7051 - val_recall_15: 0.8596 - learning_rate: 0.0010
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8553 - auc_15: 0.9292 - loss: 0.3363 - precision_15: 0.8889 - recall_15: 0.8330 - val_accuracy: 0.8176 - val_auc_15: 0.9124 - val_loss: 0.3640 - val_precision_15: 0.7654 - val_recall_15: 0.7697 - learning_rate: 0.0010
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8547 - auc_15: 0.9331 - loss: 0.3270 - precision_15: 0.8845 - recall_15: 0.8371 - val_accuracy: 0.8022 - val_auc_15: 0.9082 - val_loss: 0.4233 - val_precision_15: 0.6982 - val_recall_15: 0.8708 - learning_rate: 0.0010
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8674 - auc_15: 0.9411 - loss: 0.3061 - precision_15: 0.8865 - recall_15: 0.8619 - val_accuracy: 0.8154 - val_auc_15: 0.9055 - val_loss: 0.3906 - val_precision_15: 0.8133 - val_recall_15: 0.6854 - learning_rate: 0.0010
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8630 - auc_15: 0.9365 - loss: 0.3171 - precision_15: 0.8931 - recall_15: 0.8443 - val_accuracy: 0.7890 - val_auc_15: 0.8991 - val_loss: 0.4133 - val_precision_15: 0.7113 - val_recall_15: 0.7753 - learning_rate: 0.0010
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8685 - auc_15: 0.9411 - loss: 0.3072 - precision_15: 0.8884 - recall_15: 0.8619 - val_accuracy: 0.8066 - val_auc_15: 0.9057 - val_loss: 0.4117 - val_precision_15: 0.7163 - val_recall_15: 0.8371 - learning_rate: 0.0010
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8630 - auc_15: 0.9397 - loss: 0.3107 - precision_15: 0.8897 - recall_15: 0.8485 - val_accuracy: 0.7560 - val_auc_15: 0.8924 - val_loss: 0.4845 - val_precision_15: 0.6356 - val_recall_15: 0.8820 - learning_rate: 0.0010
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8712 - auc_15: 0.9442 - loss: 0.2990 - precision_15: 0.8890 - recall_15: 0.8670 - val_accuracy: 0.7978 - val_auc_15: 0.8948 - val_loss: 0.4296 - val_precision_15: 0.7108 - val_recall_15: 0.8146 - learning_rate: 5.0000e-04
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8806 - auc_15: 0.9516 - loss: 0.2793 - precision_15: 0.9010 - recall_15: 0.8722 - val_accuracy: 0.7824 - val_auc_15: 0.8907 - val_loss: 0.4685 - val_precision_15: 0.6756 - val_recall_15: 0.8539 - learning_rate: 5.0000e-04
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8822 - auc_15: 0.9521 - loss: 0.2785 - precision_15: 0.9030 - recall_15: 0.8732 - val_accuracy: 0.7692 - val_auc_15: 0.8953 - val_loss: 0.4737 - val_precision_15: 0.6608 - val_recall_15: 0.8427 - learning_rate: 5.0000e-04
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8811 - auc_15: 0.9507 - loss: 0.2786 - precision_15: 0.9028 - recall_15: 0.8711 - val_accuracy: 0.8110 - val_auc_15: 0.8899 - val_loss: 0.4439 - val_precision_15: 0.7447 - val_recall_15: 0.7865 - learning_rate: 5.0000e-04
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8734 - auc_15: 0.9516 - loss: 0.2776 - precision_15: 0.8928 - recall_15: 0.8670 - val_accuracy: 0.7736 - val_auc_15: 0.8834 - val_loss: 0.4643 - val_precision_15: 0.6777 - val_recall_15: 0.8034 - learning_rate: 5.0000e-04
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8855 - auc_15: 0.9551 - loss: 0.2685 - precision_15: 0.9079 - recall_15: 0.8742 - val_accuracy: 0.7692 - val_auc_15: 0.8898 - val_loss: 0.5033 - val_precision_15: 0.6567 - val_recall_15: 0.8596 - learning_rate: 2.5000e-04
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8905 - auc_15: 0.9567 - loss: 0.2643 - precision_15: 0.9088 - recall_15: 0.8835 - val_accuracy: 0.7780 - val_auc_15: 0.8891 - val_loss: 0.4927 - val_precision_15: 0.6791 - val_recall_15: 0.8202 - learning_rate: 2.5000e-04
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy: 0.8214285714285714
# Precision: 0.9281767955801105
# Recall: 0.7813953488372093
# F1: 0.8484848484848485
# ROC-AUC: 0.910128771862387
# Confusion matrix:
#  [[108  13]
#  [ 47 168]]
#               precision    recall  f1-score   support
#
#            0     0.6968    0.8926    0.7826       121
#            1     0.9282    0.7814    0.8485       215
#
#     accuracy                         0.8214       336
#    macro avg     0.8125    0.8370    0.8155       336
# weighted avg     0.8448    0.8214    0.8248       336
#
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot first 150 predictions
N = 150  

plt.figure(figsize=(18, 12))

# ------------------------------
# 1. CNN-LSTM plot
# ------------------------------
plt.subplot(3, 1, 1)
plt.plot(y_test[:N], 'o-', label="Actual", alpha=0.8)
plt.plot(y_pred_cnn[:N], 'x--', label="Predicted (CNN-LSTM)", alpha=0.8)
plt.title("Adilabad - CNN-LSTM Model: Actual vs Predicted Rain/No-Rain")
plt.ylabel("Rain (1) / No Rain (0)")
plt.legend()
plt.grid(True)

# ------------------------------
# 2. Transformer plot
# ------------------------------
plt.subplot(3, 1, 2)
plt.plot(y_test[:N], 'o-', label="Actual", alpha=0.8)
plt.plot(y_pred_tr[:N], 'x--', label="Predicted (Transformer)", alpha=0.8)
plt.title("Adilabad - Transformer Based Binary Classifier Model: Actual vs Predicted Rain/No-Rain")
plt.ylabel("Rain (1) / No Rain (0)")
plt.legend()
plt.grid(True)

# ------------------------------
# 3. TabNet + Sequence Hybrid
# ------------------------------
plt.subplot(3, 1, 3)
plt.plot(y_test[:N], 'o-', label="Actual", alpha=0.8)
plt.plot(y_pred_tab[:N], 'x--', label="Predicted (TabNet+Seq)", alpha=0.8)
plt.title("Adilabad - TabNet + Sequence (GRU+CNN) Hybrid Model: Actual vs Predicted Rain/No-Rain")
plt.xlabel("Time Steps")
plt.ylabel("Rain (1) / No Rain (0)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# --------------------------
# COLLECT METRICS FOR MODELS
# --------------------------

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

metrics = {}

def compute_metrics(y_true, y_prob):
    y_pred = (y_prob > 0.5).astype(int)
    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1": f1_score(y_true, y_pred),
        "ROC-AUC": roc_auc_score(y_true, y_prob)
    }

metrics["CNN-LSTM"] = compute_metrics(y_test, y_prob_cnn)
metrics["Transformer"] = compute_metrics(y_test, y_prob_tr)
metrics["TabNet+Seq(GRU+CNN)"] = compute_metrics(y_test, y_prob_tab)

print("\nCollected Metrics:")
metrics
# Out:
# Collected Metrics:
# {'CNN-LSTM': {'Accuracy': 0.7797619047619048,
#   'Precision': 0.937888198757764,
#   'Recall': 0.7023255813953488,
#   'F1': 0.8031914893617021,
#   'ROC-AUC': 0.8578896790313281},
#  'Transformer': {'Accuracy': 0.7857142857142857,
#   'Precision': 0.9386503067484663,
#   'Recall': 0.7116279069767442,
#   'F1': 0.8095238095238095,
#   'ROC-AUC': 0.8525850470882184},
#  'TabNet+Seq(GRU+CNN)': {'Accuracy': 0.8214285714285714,
#   'Precision': 0.9281767955801105,
#   'Recall': 0.7813953488372093,
#   'F1': 0.8484848484848485,
#   'ROC-AUC': 0.910128771862387}}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Metrics in order
metric_names = ["Accuracy", "Precision", "Recall", "F1", "ROC-AUC"]

# Model names
model_names = list(metrics.keys())

# Create matrix of metric values
values = np.array([[metrics[m][metric] * 100 for metric in metric_names] for m in model_names])

# Plot
plt.figure(figsize=(16, 8))

x = np.arange(len(metric_names))
width = 0.25  # bar width

# Colors
colors = ["#4C72B0", "#55A868", "#C44E52"]

for i, model in enumerate(model_names):
    plt.bar(x + i * width, values[i], width, label=model, color=colors[i], alpha=0.85)
    # Add value labels above bars
    for j, val in enumerate(values[i]):
        plt.text(x[j] + i * width, val + 0.3, f"{val:.2f}", ha='center', fontsize=10)

plt.xticks(x + width, metric_names, fontsize=12)
plt.ylabel("Percentage (%)", fontsize=14)
plt.title("Adilabad Model Comparison: CNN-LSTM vs Transformer vs TabNet+Seq(GRU+CNN)", fontsize=16)
plt.legend(fontsize=12,loc='lower left')
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.show()
